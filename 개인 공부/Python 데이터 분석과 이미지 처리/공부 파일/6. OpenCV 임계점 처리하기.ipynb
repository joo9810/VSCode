# %% [markdown]
# 이미지 임계점 처리하기

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('gray_image.jpg', cv2.IMREAD_GRAYSCALE)

plt.imshow(image)
plt.show()

# %%
images = []
ret, thres1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY) # ret에는 임계점인 127이 들어간다.
ret, thres2 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)
ret, thres3 = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)
ret, thres4 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO)
ret, thres5 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO_INV)

images.append(thres1)
images.append(thres2)
images.append(thres3)
images.append(thres4)
images.append(thres5)

for i in images:
    plt.imshow(cv2.cvtColor(i, cv2.COLOR_GRAY2RGB))
    plt.show()

# %% [markdown]
# 이미지 적응 임계점 처리

# %%
import cv2

image = cv2.imread('hand_writing_image.jpg')

plt.imshow(image)
plt.show()

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(image_gray)
plt.show()

ret, thres1 = cv2.threshold(image_gray, 127, 255, cv2.THRESH_BINARY) # 임계점을 직접 127로 지정
thres2 = cv2.adaptiveThreshold(image_gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 3) # 자동으로 ADAPTIVE_THRESH_MEAN_C가 임계점을 설정

plt.imshow(cv2.cvtColor(thres1, cv2.COLOR_GRAY2RGB))
plt.show()

plt.imshow(cv2.cvtColor(thres2, cv2.COLOR_GRAY2RGB))
plt.show()
