# %% [markdown]
# 이미지 크기 변경

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('cat.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

expand = cv2.resize(image, None, fx = 2.0, fy = 2.0, interpolation = cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(expand, cv2.COLOR_BGR2RGB))
plt.show()

shrink = cv2.resize(image, None, fx = 0.5, fy = 0.5, interpolation = cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(shrink, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 이미지 위치 변경

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('cat.jpg')

# 행과 열 정보만 저장합니다.
height, width = image.shape[:2]

M = np.float32([[1, 0, 50], [0, 1, 10]]) # 변환 행렬
result = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 이미지 회전

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('cat.jpg')

# 행과 열 정보만 저장합니다.
height, width = image.shape[:2]

M = cv2.getRotationMatrix2D((width / 2, height / 2), 90, 0.5) # 높이와 너비의 절반인 정 중앙을 축으로 반시계 90도 회전 (0.5는 스케일)
print(M) # 2x3 변환행렬
result = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [[ 3.061617e-17  5.000000e-01  5.200000e+01]
#  [-5.000000e-01  3.061617e-17  2.635000e+02]]
