# %% [markdown]
# ### 그룹 기록
# ex)
# group1 =
# group2 =
# ...

# %% [markdown]
# ### 전체 그룹 기록
# ex) all_group = [group1, group2, ...]

# %%
import group_make as gm

group = gm.generate_group()
group
# Out:
# {'1조': ['한세진', '김도연', '김경환', '전민규'],
#  '2조': ['곽경민', '박형준', '김영주', '김태헌'],
#  '3조': ['이동건', '박지훈', '황은혁', '도영훈'],
#  '4조': ['권도운', '안윤호', '안효준', '조혜리'],
#  '5조': ['손지원', '황지원', '이송은', '구성윤'],
#  '6조': ['김이현', '김경태', '김현주', '이민하'],
#  '7조': ['김민석', '김아란', '장재웅', '이현종'],
#  '8조': ['김환선', '박란영', '김미소', '김재성']}

# %%
# def team_make():
#     while True:
#         group = gm.generate_group()
#         for i in group:
#             if ('조혜리' in group[i]) and ('안효준' in group[i]):
#                 isOk = False
#                 break
#             else:
#                 isOk = True
#                 continue

#         if isOk == True:
#             break

#     return group

# %%
# team_make()

# %%
group1 = {'1조': ['김이현', '황은혁', '김현주', '이민하'], 
          '2조': ['안효준', '박지훈', '황지원', '김경태'], 
          '3조': ['구성윤', '이동건', '김민석', '김도연'], 
          '4조': ['곽경민', '김아란', '박란영', '김미소'], 
          '5조': ['김재성', '김태헌', '조혜리', '권도운'], 
          '6조': ['안윤호', '장재웅', '김영주', '이현종'], 
          '7조': ['손지원', '박형준', '전민규', '한세진'],
          '8조': ['김경환', '이송은', '김환선', '도영훈']}

group2 = {'1조': ['김이현', '안효준', '구성윤', '곽경민'], 
          '2조': ['김재성', '안윤호', '손지원', '김경환'], 
          '3조': ['김아란', '이동건', '박지훈', '황은혁'], 
          '4조': ['박형준', '이송은', '장재웅', '김태헌'], 
          '5조': ['김현주', '황지원', '김민석', '박란영'], 
          '6조': ['조혜리', '전민규', '김영주', '김환선'], 
          '7조': ['이민하', '김경태', '김도연', '한세진'], 
          '8조': ['이현종', '권도운', '도영훈', '김미소']}

group3 = {'1조': ['김재성', '도영훈', '박지훈', '박형준'],
         '2조': ['김경태', '김태헌', '이동건', '김이현'],
         '3조': ['이현종', '김현주', '안효준', '전민규'],
         '4조': ['황지원', '김아란', '김환선', '권도운'],
         '5조': ['손지원', '이송은', '김민석', '이민하'],
         '6조': ['김경환', '김미소', '김도연', '김영주'],
         '7조': ['박란영', '장재웅', '한세진', '구성윤'],
         '8조': ['조혜리', '곽경민', '안윤호', '황은혁']}


# 모든 프로젝트 그룹명 작성
all_group = [group1, group2]

gm.without_duplicates(all_group)
# Out:
# [{'1조': ['김이현', '황은혁', '김현주', '이민하'],
#   '2조': ['안효준', '박지훈', '황지원', '김경태'],
#   '3조': ['구성윤', '이동건', '김민석', '김도연'],
#   '4조': ['곽경민', '김아란', '박란영', '김미소'],
#   '5조': ['김재성', '김태헌', '조혜리', '권도운'],
#   '6조': ['안윤호', '장재웅', '김영주', '이현종'],
#   '7조': ['손지원', '박형준', '전민규', '한세진'],
#   '8조': ['김경환', '이송은', '김환선', '도영훈']},
#  {'1조': ['김이현', '안효준', '구성윤', '곽경민'],
#   '2조': ['김재성', '안윤호', '손지원', '김경환'],
#   '3조': ['김아란', '이동건', '박지훈', '황은혁'],
#   '4조': ['박형준', '이송은', '장재웅', '김태헌'],
#   '5조': ['김현주', '황지원', '김민석', '박란영'],
#   '6조': ['조혜리', '전민규', '김영주', '김환선'],
#   '7조': ['이민하', '김경태', '김도연', '한세진'],
#   '8조': ['이현종', '권도운', '도영훈', '김미소']},
#  {'1조': ['이현종', '박지훈', '김태헌', '구성윤'],
#   '2조': ['김도연', '김재성', '김현주', '김미소'],
#   '3조': ['김경환', '장재웅', '이민하', '황지원'],
#   '4조': ['도영훈', '김경태', '전민규', '김아란'],
#   '5조': ['곽경민', '김영주', '이송은', '권도운'],
#   '6조': ['한세진', '박란영', '김환선', '안윤호'],
#   '7조': ['이동건', '조혜리', '박형준', '김이현'],
#   '8조': ['손지원', '김민석', '안효준', '황은혁']}]
