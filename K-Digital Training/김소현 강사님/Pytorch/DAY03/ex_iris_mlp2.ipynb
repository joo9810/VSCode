# %% [markdown]
# #### iris 데이터셋 활용 꽃잎 너비 예측 모델
# - 데이터셋 : iris.csv에서 2개 Feature 사용
# - 구현 프레임워크 : Pytorch

# %% [markdown]
# - [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈 로딩
import torch                                        # 텐서 및 수치 계산 함수 관련 모듈
import torch.nn as nn                               # 인공 신경망 관련 모듈
import torch.nn.functional as F                     # 손실, 거리 등 함수 관련 모듈
import torch.optim as optim                         # 최적화 기법 관련 모듈
from torchmetrics.regression import R2Score         # 성능 지표 관련 모듈 - 추가 설치
from torchinfo import summary                       # 모델 정보 관련 모듈 - 추가 설치

import pandas as pd                                 # 데이터 파일 분석 관련 모듈
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 모델의 가중치 및 절편 값 고정 설정
torch.manual_seed(1)

# 저장 및 실행 위치 설정
Device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'DEVICE => {Device}')
# Out:
# DEVICE => cpu

# %%
# 데이터 로딩 : CSV => DataFrame
DATA_FILE = '/Users/anhyojun/VSCode/K-Digital Training/Data/iris.csv'

irisDF = pd.read_csv(DATA_FILE, usecols=[0,1,2,3])
irisDF.head(2)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2

# %% [markdown]
# [2] 모델 준비
# - 학습 방법 : 지도학습 > 회귀
# - 알고리즘 : 선형관계 >> 선형모델 ==> nn.Linear

# %%
# 모델 설계
# 입력층의 입력값/피처 => sepal.length, sepal.width, petal.length     3개
# 출력층의 출력값/타겟 => petal.width        1개
# 입력층    : 입력 : 피처3 / 출력 : 입력층에 존재하는 퍼센트론 개수 10 / AF : ReLU
# 은닉층    : 입력 :   10 / 출력 : 은닉층에 존재하는 퍼셉트론 개수 5 / AF : ReLU
# 출력층    : 입력 :   5  / 출력 : 타겟/라벨 개수 1  / AF : None (선형회귀일 경우 출력 시 활성함수 없어도 됨)

model = nn.Sequential(nn.Linear(3,10),
                         nn.ReLU(),
                         nn.Linear(10,5),
                         nn.ReLU(),
                         nn.Linear(5,1))

# %%
# 모델 구조 확인
print(model)
summary(model, input_size=(150,3))
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=5, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=5, out_features=1, bias=True)
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [150, 1]                  --
# ├─Linear: 1-1                            [150, 10]                 40
# ├─ReLU: 1-2                              [150, 10]                 --
# ├─Linear: 1-3                            [150, 5]                  55
# ├─ReLU: 1-4                              [150, 5]                  --
# ├─Linear: 1-5                            [150, 1]                  6
# ==========================================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# Total mult-adds (M): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.02
# ==========================================================================================

# %%
# 가중치와 절편 확인
for name, param in model.named_parameters():
    print(f'[{name}] {param}\n')
# Out:
# [0.weight] Parameter containing:
# tensor([[ 0.2975, -0.2548, -0.1119],
#         [ 0.2710, -0.5435,  0.3462],
#         [-0.1188,  0.2937,  0.0803],
#         [-0.0707,  0.1601,  0.0285],
#         [ 0.2109, -0.2250, -0.0421],
#         [-0.0520,  0.0837, -0.0023],
#         [ 0.5047,  0.1797, -0.2150],
#         [-0.3487, -0.0968, -0.2490],
#         [-0.1850,  0.0276,  0.3442],
#         [ 0.3138, -0.5644,  0.3579]], requires_grad=True)
#
# [0.bias] Parameter containing:
# tensor([ 0.1613,  0.5476,  0.3811, -0.5260, -0.5489, -0.2785,  0.5070, -0.0962,
#          0.2471, -0.2683], requires_grad=True)
#
# [2.weight] Parameter containing:
# tensor([[ 0.3103, -0.1338,  0.2371,  0.0037, -0.1666,  0.1625, -0.1679,  0.0930,
#          -0.0913, -0.0347],
#         [-0.3040, -0.1508,  0.1716, -0.0769,  0.3150,  0.2535, -0.0148, -0.2111,
#           0.1926,  0.0981],
#         [-0.2044,  0.2054,  0.1920,  0.2805, -0.1773, -0.0521, -0.0061,  0.0462,
#          -0.2400, -0.2244],
#         [ 0.1720, -0.0742,  0.1545,  0.0180,  0.1038,  0.0695,  0.1150,  0.1568,
#          -0.2929,  0.1592],
#         [-0.2223, -0.2386,  0.0192, -0.0539,  0.1857, -0.1831, -0.2811,  0.2301,
#          -0.0469,  0.1779]], requires_grad=True)
#
# [2.bias] Parameter containing:
# tensor([ 0.1017, -0.2371,  0.0635,  0.0760, -0.2117], requires_grad=True)
#
# [4.weight] Parameter containing:
# tensor([[-0.2122,  0.1525,  0.0801, -0.1902, -0.1354]], requires_grad=True)
#
# [4.bias] Parameter containing:
# tensor([0.4096], requires_grad=True)

# %% [markdown]
# [3] 최적화 인스턴스 준비

# %%
### 모델의 가중치와 절편을 최적화 ==> 인스턴스에 전달
adam_optim = optim.Adam(model.parameters(), lr=0.1)

# %% [markdown]
# [4] 학습 ==> 개발자가 구현

# %% [markdown]
# - [4-1] 데이터셋 Tensor화 진행 : 데이터 준비 시 진행하거나 학습 전 진행

# %%
# 피쳐와 타겟 분리
featureDF = irisDF[irisDF.columns[:-1]]
targetDF = irisDF[['petal.width']]

print(featureDF.shape, targetDF.shape)
# Out:
# (150, 3) (150, 1)

# %%
# Train & Test
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetDF, test_size=0.2, random_state=5)

# Train & Valid
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=5)

print(f'[Feature] TRAIN {X_train.shape}, TEST {X_test.shape}, VAL {X_val.shape}')
print(f'[Target]  TRAIN {y_train.shape}, TEST {y_test.shape}, VAL {y_val.shape}')
# Out:
# [Feature] TRAIN (96, 3), TEST (30, 3), VAL (24, 3)
# [Target]  TRAIN (96, 1), TEST (30, 1), VAL (24, 1)

# %% [markdown]
# - [4-2] 학습 진행
#     * 학습 횟수 결정 ==> 에포크 설정
#     * 배치 크기 결정
#     * 배치 개수 계산

# %%
EPOCH = 100                                # 처음부터 끝까지 공부하는 횟수
BATCH_SIZE = 12                            # 1에포크에서 한번에 학습할 분량 크기
BATCH_CNT = X_train.shape[0]//BATCH_SIZE   # 1에포크에서 총 학습 횟수이면서 가중치 업데이트 횟수

print(f'EPOCH : {EPOCH}, BATCH_SIZE : {BATCH_SIZE}, BATCH_CNT : {BATCH_CNT}')
# Out:
# EPOCH : 100, BATCH_SIZE : 12, BATCH_CNT : 8

# %%
## 테스트/검증 함수 
# ==> 가중치, 절편 업데이트 X, 최적화 미진행
# ==> 현재 가중치와 절편값으로 테스트 진행
def testing(testDF, targetDF, kind='Val'):
    # Tensor화
    testTS = torch.FloatTensor(testDF.values).to(Device)
    targetTS = torch.FloatTensor(targetDF.values).to(Device)

    with torch.no_grad():   # 가중치, 절편 업데이트 X
        # (1) 학습 진행 - forward
        pre_y = model(testTS)
        print(f'{pre_y.shape}')
        
        # (2) 오차 계산 - 손실 함수
        loss = F.mse_loss(pre_y, targetTS)

        # (3) 성능평가 - R2
        r2 = R2Score()(pre_y, targetTS)

        # (4) 학습 결과 출력 및 저장
        print(f'[{kind}] Loss : {loss}, R2 : {r2}')

    return loss, r2

# %%
# 모델 학습 함수
def training(featureTS, targetTS, valTS, valTargetTS):
    # [[],[]] <= [train, val]
    loss_history = [[],[]]
    r2_history = [[],[]]
    
    for epoch in range(EPOCH):
        # 배치 손실 저장 변수
        batch_loss, batch_r2 = 0, 0

        # 배치 크기만큼 학습 진행
        for i in range(BATCH_CNT):
            start = i*BATCH_SIZE
            end = start+BATCH_SIZE

            # BS크기만큼만 데이터 추출해서 Tensor화 진행
            BSX_train = torch.FloatTensor(X_train[start:end].values).to(Device)
            BSy_train = torch.FloatTensor(y_train[start:end].values).to(Device)
            print(f'X_train : {BSX_train.shape}, {BSX_train.device}, {BSX_train.dtype}')
            print(f'y_train : {BSy_train.shape}, {BSy_train.device}, {BSy_train.dtype}')

            # (1) 학습 진행 - forward
            pre_y = model(BSX_train)

            # (2) 오차 계산 - 손실 함수
            loss = F.mse_loss(pre_y, BSy_train)
            batch_loss += loss.item()
            batch_r2 += R2Score()(pre_y, BSy_train).item()
            # loss_history[0].append(loss.item())

            # (3) 최적화 -  가중치, 절편, 업데이트 backward
            adam_optim.zero_grad()
            loss.backward()
            adam_optim.step()

        # (4) 검증 - 모델이 제대로 만들어 지는지 검사
        val_loss, val_r2 = testing(valTS, valTargetTS)
        loss_history[1].append(val_loss.item())
        r2_history[1].append(val_r2.item())

        # 에포크 단위 손실과 성능지표
        loss_history[0].append(batch_loss/BATCH_CNT)
        r2_history[0].append(batch_r2/BATCH_CNT)

        # (5) 학습 결과 출력 및 저장
        print(f'[{epoch}/{EPOCH}]\nTrain Loss : {loss_history[0][-1]}, R2 : {r2_history[0][-1]}')
        print(f'-Validation Loss : {loss_history[1][-1]}, R2 : {r2_history[1][-1]}')

    return loss_history, r2_history

# %%
# 모델 학습 진행
loss, r2 = training(X_train, y_train, X_val, y_val)
# Out:
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.4191381633281708, R2 : -0.004299283027648926
# [0/100]
# Train Loss : 0.9069786705076694, R2 : -0.5297544598579407
# -Validation Loss : 0.4191381633281708, R2 : -0.004299283027648926
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.49096497893333435, R2 : -0.17640399932861328
# [1/100]
# Train Loss : 0.6465997360646725, R2 : -0.10939279198646545
# -Validation Loss : 0.49096497893333435, R2 : -0.17640399932861328
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.44149693846702576, R2 : -0.05787336826324463
# [2/100]
# Train Loss : 0.6715940572321415, R2 : -0.1355888992547989
# -Validation Loss : 0.44149693846702576, R2 : -0.05787336826324463
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.3640384376049042, R2 : 0.12772542238235474
# [3/100]
# Train Loss : 0.600370779633522, R2 : -0.018216438591480255
# -Validation Loss : 0.3640384376049042, R2 : 0.12772542238235474
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.26617199182510376, R2 : 0.362223744392395
# [4/100]
# Train Loss : 0.4600764084607363, R2 : 0.24171628803014755
# -Validation Loss : 0.26617199182510376, R2 : 0.362223744392395
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.031690564006567, R2 : 0.9240660667419434
# [5/100]
# Train Loss : 0.19732996402308345, R2 : 0.6738923415541649
# -Validation Loss : 0.031690564006567, R2 : 0.9240660667419434
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.05004154518246651, R2 : 0.8800951838493347
# [6/100]
# Train Loss : 0.07605535839684308, R2 : 0.8713959157466888
# -Validation Loss : 0.05004154518246651, R2 : 0.8800951838493347
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.15743207931518555, R2 : 0.6227760910987854
# [7/100]
# Train Loss : 0.10083180759102106, R2 : 0.8307994902133942
# -Validation Loss : 0.15743207931518555, R2 : 0.6227760910987854
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.048974860459566116, R2 : 0.8826510310173035
# [8/100]
# Train Loss : 0.07504427898675203, R2 : 0.8719117417931557
# -Validation Loss : 0.048974860459566116, R2 : 0.8826510310173035
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.02901413105428219, R2 : 0.9304790496826172
# [9/100]
# Train Loss : 0.05300591536797583, R2 : 0.9114316701889038
# -Validation Loss : 0.02901413105428219, R2 : 0.9304790496826172
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.02775578945875168, R2 : 0.9334942102432251
# [10/100]
# Train Loss : 0.04644338134676218, R2 : 0.9226039499044418
# -Validation Loss : 0.02775578945875168, R2 : 0.9334942102432251
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03179356828331947, R2 : 0.9238192439079285
# [11/100]
# Train Loss : 0.044794893357902765, R2 : 0.925303153693676
# -Validation Loss : 0.03179356828331947, R2 : 0.9238192439079285
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.035302042961120605, R2 : 0.9154125452041626
# [12/100]
# Train Loss : 0.04483350971713662, R2 : 0.9251430779695511
# -Validation Loss : 0.035302042961120605, R2 : 0.9154125452041626
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03462836146354675, R2 : 0.9170267581939697
# [13/100]
# Train Loss : 0.044986218912526965, R2 : 0.9247607290744781
# -Validation Loss : 0.03462836146354675, R2 : 0.9170267581939697
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.032086025923490524, R2 : 0.9231184720993042
# [14/100]
# Train Loss : 0.044349461095407605, R2 : 0.9258357957005501
# -Validation Loss : 0.032086025923490524, R2 : 0.9231184720993042
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.0312873013317585, R2 : 0.9250323176383972
# [15/100]
# Train Loss : 0.04325702856294811, R2 : 0.9277524277567863
# -Validation Loss : 0.0312873013317585, R2 : 0.9250323176383972
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03202146664261818, R2 : 0.9232732057571411
# [16/100]
# Train Loss : 0.04266189830377698, R2 : 0.9288515895605087
# -Validation Loss : 0.03202146664261818, R2 : 0.9232732057571411
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03202090784907341, R2 : 0.9232745170593262
# [17/100]
# Train Loss : 0.042554138926789165, R2 : 0.9290515631437302
# -Validation Loss : 0.03202090784907341, R2 : 0.9232745170593262
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.031271886080503464, R2 : 0.925069272518158
# [18/100]
# Train Loss : 0.04229464172385633, R2 : 0.9294372349977493
# -Validation Loss : 0.031271886080503464, R2 : 0.925069272518158
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.031152531504631042, R2 : 0.9253552556037903
# [19/100]
# Train Loss : 0.04175850562751293, R2 : 0.930305540561676
# -Validation Loss : 0.031152531504631042, R2 : 0.9253552556037903
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.031436678022146225, R2 : 0.924674391746521
# [20/100]
# Train Loss : 0.041321969125419855, R2 : 0.9310398325324059
# -Validation Loss : 0.031436678022146225, R2 : 0.924674391746521
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03131832927465439, R2 : 0.9249579906463623
# [21/100]
# Train Loss : 0.041047520469874144, R2 : 0.931487038731575
# -Validation Loss : 0.03131832927465439, R2 : 0.9249579906463623
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03121480531990528, R2 : 0.9252060055732727
# [22/100]
# Train Loss : 0.04071665299125016, R2 : 0.932021863758564
# -Validation Loss : 0.03121480531990528, R2 : 0.9252060055732727
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03139543905854225, R2 : 0.9247732162475586
# [23/100]
# Train Loss : 0.04036544845439494, R2 : 0.9326009601354599
# -Validation Loss : 0.03139543905854225, R2 : 0.9247732162475586
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03150176629424095, R2 : 0.9245184659957886
# [24/100]
# Train Loss : 0.04008348099887371, R2 : 0.9330518841743469
# -Validation Loss : 0.03150176629424095, R2 : 0.9245184659957886
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03163551911711693, R2 : 0.9241979718208313
# [25/100]
# Train Loss : 0.03979466622695327, R2 : 0.9335082992911339
# -Validation Loss : 0.03163551911711693, R2 : 0.9241979718208313
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.031856510788202286, R2 : 0.9236684441566467
# [26/100]
# Train Loss : 0.039511944400146604, R2 : 0.9339564293622971
# -Validation Loss : 0.031856510788202286, R2 : 0.9236684441566467
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.032041385769844055, R2 : 0.923225462436676
# [27/100]
# Train Loss : 0.03926538792438805, R2 : 0.9343346655368805
# -Validation Loss : 0.032041385769844055, R2 : 0.923225462436676
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.032289374619722366, R2 : 0.9226312637329102
# [28/100]
# Train Loss : 0.03902177209965885, R2 : 0.9347054958343506
# -Validation Loss : 0.032289374619722366, R2 : 0.9226312637329102
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03255735710263252, R2 : 0.9219891428947449
# [29/100]
# Train Loss : 0.03880186774767935, R2 : 0.9350313171744347
# -Validation Loss : 0.03255735710263252, R2 : 0.9219891428947449
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03284792974591255, R2 : 0.9212929010391235
# [30/100]
# Train Loss : 0.038599238730967045, R2 : 0.9353231936693192
# -Validation Loss : 0.03284792974591255, R2 : 0.9212929010391235
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.033170681446790695, R2 : 0.9205195307731628
# [31/100]
# Train Loss : 0.03841299284249544, R2 : 0.935584768652916
# -Validation Loss : 0.033170681446790695, R2 : 0.9205195307731628
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03350415453314781, R2 : 0.9197205305099487
# [32/100]
# Train Loss : 0.03824870614334941, R2 : 0.9358047097921371
# -Validation Loss : 0.03350415453314781, R2 : 0.9197205305099487
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03386625275015831, R2 : 0.9188528656959534
# [33/100]
# Train Loss : 0.03810022305697203, R2 : 0.9359959587454796
# -Validation Loss : 0.03386625275015831, R2 : 0.9188528656959534
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03254012390971184, R2 : 0.9220304489135742
# [34/100]
# Train Loss : 0.037960260873660445, R2 : 0.9361854046583176
# -Validation Loss : 0.03254012390971184, R2 : 0.9220304489135742
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03323192521929741, R2 : 0.9203727841377258
# [35/100]
# Train Loss : 0.037521621910855174, R2 : 0.9369604960083961
# -Validation Loss : 0.03323192521929741, R2 : 0.9203727841377258
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.033770203590393066, R2 : 0.9190829992294312
# [36/100]
# Train Loss : 0.037400960456579924, R2 : 0.937194474041462
# -Validation Loss : 0.033770203590393066, R2 : 0.9190829992294312
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.033728182315826416, R2 : 0.9191837310791016
# [37/100]
# Train Loss : 0.03750418685376644, R2 : 0.9368719533085823
# -Validation Loss : 0.033728182315826416, R2 : 0.9191837310791016
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03484595566987991, R2 : 0.9165053963661194
# [38/100]
# Train Loss : 0.03719843039289117, R2 : 0.9374069646000862
# -Validation Loss : 0.03484595566987991, R2 : 0.9165053963661194
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.034885551780462265, R2 : 0.916410505771637
# [39/100]
# Train Loss : 0.037370501551777124, R2 : 0.9369804337620735
# -Validation Loss : 0.034885551780462265, R2 : 0.916410505771637
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.035832103341817856, R2 : 0.9141424894332886
# [40/100]
# Train Loss : 0.03708636318333447, R2 : 0.9375264868140221
# -Validation Loss : 0.035832103341817856, R2 : 0.9141424894332886
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03577354922890663, R2 : 0.9142827987670898
# [41/100]
# Train Loss : 0.03735385800246149, R2 : 0.9369102790951729
# -Validation Loss : 0.03577354922890663, R2 : 0.9142827987670898
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.036851201206445694, R2 : 0.9117006063461304
# [42/100]
# Train Loss : 0.0370316308690235, R2 : 0.9375386238098145
# -Validation Loss : 0.036851201206445694, R2 : 0.9117006063461304
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.036768071353435516, R2 : 0.9118998050689697
# [43/100]
# Train Loss : 0.03739801177289337, R2 : 0.9367158189415932
# -Validation Loss : 0.036768071353435516, R2 : 0.9118998050689697
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03755366802215576, R2 : 0.9100174307823181
# [44/100]
# Train Loss : 0.037019270355813205, R2 : 0.9374491795897484
# -Validation Loss : 0.03755366802215576, R2 : 0.9100174307823181
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03773616999387741, R2 : 0.9095801711082458
# [45/100]
# Train Loss : 0.037408043863251805, R2 : 0.936606802046299
# -Validation Loss : 0.03773616999387741, R2 : 0.9095801711082458
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.03821658715605736, R2 : 0.9084290266036987
# [46/100]
# Train Loss : 0.037066514254547656, R2 : 0.9372772723436356
# -Validation Loss : 0.03821658715605736, R2 : 0.9084290266036987
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# ...
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04137219861149788, R2 : 0.9008678197860718
# [84/100]
# Train Loss : 0.03760419157333672, R2 : 0.9357351958751678
# -Validation Loss : 0.04137219861149788, R2 : 0.9008678197860718
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04138055816292763, R2 : 0.9008477926254272
# [85/100]
# Train Loss : 0.037605921970680356, R2 : 0.9357279911637306
# -Validation Loss : 0.04138055816292763, R2 : 0.9008477926254272
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.0413874126970768, R2 : 0.900831401348114
# [86/100]
# Train Loss : 0.03760688588954508, R2 : 0.9357225298881531
# -Validation Loss : 0.0413874126970768, R2 : 0.900831401348114
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04139477014541626, R2 : 0.9008137583732605
# [87/100]
# Train Loss : 0.03760834236163646, R2 : 0.9357161521911621
# -Validation Loss : 0.04139477014541626, R2 : 0.9008137583732605
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.041401077061891556, R2 : 0.9007986783981323
# [88/100]
# Train Loss : 0.03760921349748969, R2 : 0.9357110932469368
# -Validation Loss : 0.041401077061891556, R2 : 0.9007986783981323
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04140784218907356, R2 : 0.9007824063301086
# [89/100]
# Train Loss : 0.03761045902501792, R2 : 0.9357053488492966
# -Validation Loss : 0.04140784218907356, R2 : 0.9007824063301086
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04141354560852051, R2 : 0.9007687568664551
# [90/100]
# Train Loss : 0.03761124552693218, R2 : 0.9357006847858429
# -Validation Loss : 0.04141354560852051, R2 : 0.9007687568664551
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04141976311802864, R2 : 0.9007538557052612
# [91/100]
# Train Loss : 0.037612303043715656, R2 : 0.9356955364346504
# -Validation Loss : 0.04141976311802864, R2 : 0.9007538557052612
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04142497479915619, R2 : 0.9007413983345032
# [92/100]
# Train Loss : 0.03761302016209811, R2 : 0.9356911703944206
# -Validation Loss : 0.04142497479915619, R2 : 0.9007413983345032
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04143063351511955, R2 : 0.9007278084754944
# [93/100]
# Train Loss : 0.03761392261367291, R2 : 0.9356865510344505
# -Validation Loss : 0.04143063351511955, R2 : 0.9007278084754944
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.041435521095991135, R2 : 0.9007161259651184
# [94/100]
# Train Loss : 0.03761457314249128, R2 : 0.9356825277209282
# -Validation Loss : 0.041435521095991135, R2 : 0.9007161259651184
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04144061729311943, R2 : 0.9007039070129395
# [95/100]
# Train Loss : 0.03761533822398633, R2 : 0.9356783255934715
# -Validation Loss : 0.04144061729311943, R2 : 0.9007039070129395
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04144524410367012, R2 : 0.9006928205490112
# [96/100]
# Train Loss : 0.03761590213980526, R2 : 0.9356746226549149
# -Validation Loss : 0.04144524410367012, R2 : 0.9006928205490112
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04144992679357529, R2 : 0.9006816148757935
# [97/100]
# Train Loss : 0.03761656419374049, R2 : 0.935670793056488
# -Validation Loss : 0.04144992679357529, R2 : 0.9006816148757935
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.04145422205328941, R2 : 0.9006713032722473
# [98/100]
# Train Loss : 0.03761703672353178, R2 : 0.9356674179434776
# -Validation Loss : 0.04145422205328941, R2 : 0.9006713032722473
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# X_train : torch.Size([12, 3]), cpu, torch.float32
# y_train : torch.Size([12, 1]), cpu, torch.float32
# torch.Size([24, 1])
# [Val] Loss : 0.041458580642938614, R2 : 0.9006608724594116
# [99/100]
# Train Loss : 0.03761762159410864, R2 : 0.9356639236211777
# -Validation Loss : 0.041458580642938614, R2 : 0.9006608724594116

# %%
# 학습 후 loss 시각화'
threshold = 100
fg, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].plot(range(1,threshold+1),loss[0][:threshold], label='Train')
axes[0].plot(range(1,threshold+1),loss[1][:threshold], label='Val')
axes[0].grid('--')
axes[0].legend()
axes[0].set_xlabel('EPOCH')
axes[0].set_ylabel('Loss')
axes[0].set_title('LOSS')

axes[1].plot(range(1,threshold+1),r2[0][:threshold], label='Train')
axes[1].plot(range(1,threshold+1),r2[1][:threshold], label='Val')
axes[1].grid('--')
axes[1].legend()
axes[1].set_xlabel('EPOCH')
axes[1].set_ylabel('R2')
axes[1].set_title('R2')
plt.show()
