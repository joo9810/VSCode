# %% [markdown]
# ## 정규 표현식 예제 #1

# %%
import re

# compile() 사용 안함
m = re.match('[a-z]+', 'Python') # 못찾음
print(m)
print(re.match('[a-z]+', 'pythoN')) # pytho
print(re.search('apple', 'I like apple!')) # apple

# compile() 사용: 객체 생성
p = re.compile('[a-z]+') # 알파벳 소문자
m = p.match('python') # python
print(m)
print(p.search('I like apple 123')) # like
# Out:
# None
# <re.Match object; span=(0, 5), match='pytho'>
# <re.Match object; span=(7, 12), match='apple'>
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(2, 6), match='like'>

# %% [markdown]
# ## 정규 표현식 예제 #2

# %%
m = re.match('[a-z]+', 'pythoN') # 소문자가 1개 이상
print(m)
# Out:
# <re.Match object; span=(0, 5), match='pytho'>

# %%
m = re.match('[a-z]+', 'PYthon') # 소문자가 1개 이상
print(m)
# Out:
# None

# %%
print(re.match('[a-z]+', 'regex python'))
print(re.match('[a-z]+', ' regexpython')) # 문자열 처음에 공백 포함

print(re.match('[a-z]+', 'regexpythoN'))
print(re.match('[a-z]+$', 'regexpythoN')) # 문자열의 마지막에 소문자 1회 이상 검사

print(re.match('[a-z]+', 'regexPython'))
print(re.match('[a-z]+$', 'regexpython'))
# Out:
# <re.Match object; span=(0, 5), match='regex'>
# None
# <re.Match object; span=(0, 10), match='regexpytho'>
# None
# <re.Match object; span=(0, 5), match='regex'>
# <re.Match object; span=(0, 11), match='regexpython'>

# %% [markdown]
# ## 정규 표현식 예제 #3

# %%
p = re.compile('[a-z]+') # 알파벳 소문자

print(p.findall('life is too short! Regular expression text'))
# Out:
# ['life', 'is', 'too', 'short', 'egular', 'expression', 'text']

# %%
result = p.search('I like apple 123')
print(result)

result = p.findall('I like apple 123')
print(result)
# Out:
# <re.Match object; span=(2, 6), match='like'>
# ['like', 'apple']

# %% [markdown]
# ## Match 메소드 예제 #1

# %%
import re
# ^ .. $ 을 명시해야 정확한 자리수 검사가 이루어짐
tel_checker = re.compile(r'^(\d{2,3})-(\d{3,4})-(\d{4})$')

print(tel_checker.match('02-123-4567'))

match_groups1 = tel_checker.match('02-123-4567').group()
match_groups2 = tel_checker.match('02-123-4567').groups()
print(match_groups1)
print(match_groups2)

print(tel_checker.match('053-950-45678'))
print(tel_checker.match('053950-4567'))
# Out:
# <re.Match object; span=(0, 11), match='02-123-4567'>
# 02-123-4567
# ('02', '123', '4567')
# None
# None

# %% [markdown]
# ## Match 메소드 예제 #2

# %%
tel_number = '053-950-4567'
tel_number = tel_number.replace('-', '')
print(tel_number)

tel_checker1 = re.compile(r'^(\d{2,3})(\d{3,4})(\d{4})$')
print(tel_checker1.match(tel_number))
print(tel_checker1.match('0239501234')) # 02-3950-1234
# Out:
# 0539504567
# <re.Match object; span=(0, 10), match='0539504567'>
# <re.Match object; span=(0, 10), match='0239501234'>

# %% [markdown]
# ## Match 메소드 예제 #3

# %%
tel_checker = re.compile(r'^(\d{2,3})-(\d{3,4})-(\d{4})$')
m = tel_checker.match('02-123-4567')

print(m.groups())
print('group(): ', m.group())
print('group(): ', m.group(0))
print('group(): ', m.group(1))
print('group(): ', m.group(2,3))
print('group(): ', m.start()) # 매칭된 문자열의 시작 인덱스
print('group(): ', m.end()) # 매칭된 문자열의 마지막 인덱스 + 1
# Out:
# ('02', '123', '4567')
# group():  02-123-4567
# group():  02-123-4567
# group():  02
# group():  ('123', '4567')
# group():  0
# group():  11

# %%
cell_phone = re.compile(r'^(01(?:0|1|[6-9]))-(\d{3,4})-(\d{4})$')

print(cell_phone.match('010-123-4567'))
print(cell_phone.match('019-1234-5678'))
print(cell_phone.match('001-123-4567')) # 01로 시작하지 않아 None
print(cell_phone.match('010-1234567')) # -가 없어서 None
# Out:
# <re.Match object; span=(0, 12), match='010-123-4567'>
# <re.Match object; span=(0, 13), match='019-1234-5678'>
# None
# None

# %% [markdown]
# ## 전방 탐색 (lookahead)

# %%
import re

# 전방 긍정 탐색: (문자열이 won을 포함하고 있으면 won 앞의 문자열 리턴)
lookahead1 = re.search('.+(?=won)', '1000 won') # won이 있으면서 앞에 문자 1개 이상
if (lookahead1 != None):
    print(lookahead1.group())
else:
    print('None')
lookahead2 = re.search('.+(?=am)', '2023-01-26 am 10:00:01') # am이 있으면서 앞에 문자 1개 이상
print(lookahead2.group())
# 전방 부정 탐색 (?!): 4자리 숫자 다음에 '-'를 포함하지 않으면 앞의 문자열 리턴
lookahead3 = re.search('\d{4}(?!-)', '010-1234-5678') # -가 없으면서 앞에 숫자 4개
print(lookahead3)
# Out:
# 1000
# 2023-01-26
# <re.Match object; span=(9, 13), match='5678'>

# %% [markdown]
# ## 후방 탐색(lookbehind)

# %%
# 후방 긍정 탐색 ('am' 다음에 문자가 1개 이상 있으면, 해당 문자열 리턴)
lookbehind1 = re.search('(?<=am).+', '2023-01-26 am 11:10:01') # am이 있으면서 뒤에 문자 1개 이상
print(lookbehind1)

lookbehind2 = re.search('(?<=:).+', 'USD: $51') # :이 있으면서 뒤에 문자 1개 이상
print(lookbehind2)

# 후방 부정 탐색('\b': 공백)
# 공백 다음에 $기호가 없고 숫자가 1개 이상이고 공백이 있는 경우
lookbehind4 = re.search(r'\b(?<!\$)\d+\b', 'I paid $30 for 100 apples.')
# $가 없으면서 앞에 공백 뒤에 숫자 + 공백
print(lookbehind4)
# Out:
# <re.Match object; span=(13, 22), match=' 11:10:01'>
# <re.Match object; span=(4, 8), match=' $51'>
# <re.Match object; span=(15, 18), match='100'>

# %% [markdown]
# ## 정규 표현식과 BeautifulSoup #1

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://www.pythonscraping.com/pages/page3.html')
soup = BeautifulSoup(html, 'html.parser')

# 정규식: ('img.*\.jpg'): img 다음에 임의의 한 문자가 0회 이상
# - img.jpg, img1.jpg, imga.jpg 등
img_tag = re.compile('/img/gifts/img.*.jpg') # .*: 아무 문자 0개 이상
# find_all()에서 img의 src 속성값에 정규식 사용
images = soup.find_all('img', {'src': img_tag})

for image in images:
    print(image, end=" -> ['src'] 속성값: ")
    print(image['src'])
# Out:
# <img src="../img/gifts/img1.jpg"/> -> ['src'] 속성값: ../img/gifts/img1.jpg
# <img src="../img/gifts/img2.jpg"/> -> ['src'] 속성값: ../img/gifts/img2.jpg
# <img src="../img/gifts/img3.jpg"/> -> ['src'] 속성값: ../img/gifts/img3.jpg
# <img src="../img/gifts/img4.jpg"/> -> ['src'] 속성값: ../img/gifts/img4.jpg
# <img src="../img/gifts/img6.jpg"/> -> ['src'] 속성값: ../img/gifts/img6.jpg

# %% [markdown]
# ## 정규 표현식과 BeautifulSoup #2

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://www.pythonscraping.com/pages/warandpeace.html')
bs = BeautifulSoup(html, 'html.parser')

princeList = bs.find_all(string = 'the prince')
print('the prince count: ', len(princeList))

prince_list = bs.find_all(string = re.compile('[T|t]{1}he prince'))
print('T|the prince count:', len(prince_list))
# Out:
# the prince count:  7
# T|the prince count: 11

# %% [markdown]
# ## Wikipedia 페이지 가져오기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1231003484
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1231003484&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_in_2022.jpg
# /wiki/Peabody_Awards
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-6
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-10
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-11
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-12
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-13
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-14
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-15
# /wiki/Footloose_(1984_film)
# #cite_note-bio-13
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-16
# #cite_note-bacon-7
# #cite_note-17
# #cite_note-18
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-19
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-13
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-20
# /wiki/Tremors_(1990_film)
# #cite_note-21
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-13
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-13
# /wiki/The_New_York_Times
# #cite_note-nyt94-22
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-23
# /wiki/A_Few_Good_Men_(film)
# #cite_note-24
# /wiki/Michael_Greif
# #cite_note-bio-13
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-13
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-13
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-25
# /wiki/Sleepers_(film)
# #cite_note-26
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-13
# /wiki/Losing_Chase
# #cite_note-austin-27
# /wiki/Digging_to_China
# #cite_note-bio-13
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-13
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-28
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-29
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-30
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-31
# /wiki/My_Dog_Skip_(film)
# #cite_note-32
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-33
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-34
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-35
# #cite_note-36
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-37
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-38
# #cite_note-39
# /wiki/The_Following
# #cite_note-40
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-41
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-42
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-43
# /wiki/Instagram
# #cite_note-44
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-45
# /wiki/EE_(telecommunications)
# #cite_note-46
# #cite_note-47
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-49
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-50
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-51
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-11
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /w/index.php?title=Travis_Sedgwick&action=edit&redlink=1
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-52
# /wiki/Tracy_Pollan
# #cite_note-53
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-54
# #cite_note-55
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-56
# /wiki/Antireligion
# #cite_note-57
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-58
# #cite_note-59
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-60
# #cite_note-61
# #cite_note-62
# #cite_note-63
# /wiki/Apollo_13_(film)
# #cite_note-64
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-65
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-66
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-67
# /wiki/Denver_Film_Festival
# #cite_note-68
# /wiki/Phoenix_Film_Festival
# #cite_note-69
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-70
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-71
# /wiki/Seattle_International_Film_Festival
# #cite_note-72
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-6
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_10-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_11-0
# #cite_ref-cosmo91_11-1
# #cite_ref-12
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_13-0
# #cite_ref-bio_13-1
# #cite_ref-bio_13-2
# #cite_ref-bio_13-3
# #cite_ref-bio_13-4
# #cite_ref-bio_13-5
# #cite_ref-bio_13-6
# #cite_ref-bio_13-7
# #cite_ref-bio_13-8
# #cite_ref-bio_13-9
# #cite_ref-bio_13-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_14-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-15
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_16-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-17
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-18
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-19
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-20
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-21
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_22-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-23
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-24
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-25
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-26
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_27-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-28
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-29
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-30
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-31
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-32
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-33
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-34
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-35
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-36
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_37-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_38-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-39
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-40
# http://www.fox.com/the-following/
# #cite_ref-41
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-42
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-43
# http://baconbros.com/
# #cite_ref-44
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-45
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-46
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-47
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-48
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-49
# http://www.sixdegrees.org/
# #cite_ref-50
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-51
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-52
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-53
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-54
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-55
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-56
# #cite_ref-57
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_58-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-59
# #cite_ref-60
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-61
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-62
# http://www.drawtheline.org/sign-now/
# #cite_ref-63
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-64
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-65
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-66
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-67
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-68
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-71
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-72
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# http://id.worldcat.org/fast/242183/
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://cantic.bnc.cat/registre/981061093903206706
# https://d-nb.info/gnd/124109659
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://lod.nl.go.kr/resource/KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://www.idref.fr/067287832
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1231003484
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_WorldCat_Entities_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_CANTICN_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# //wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org

# %% [markdown]
# ## 연관 기사 링크 찾기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
body_content = bs.find('div', {'id' : 'bodyContent'})

pattern = '^(/wiki/)((?!:).)*$'
for link in body_content.find_all('a', href = re.compile(pattern)):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Peabody_Awards
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# ## 링크간 무작위 이동하기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import random
import re

# random.seed(datetime.datetime.now())
random.seed(None) # Python 3.9 이상

def getLinks(articleUrl):
    html = urlopen('https://en.wikipedia.org' + articleUrl)
    bs = BeautifulSoup(html, 'html.parser')
    bodyContent = bs.find('div', {'id' : 'bodyContent'})
    wikiUrl = bodyContent.find_all('a', href = re.compile('^(/wiki/)((?!:).)*$'))
    return wikiUrl

links = getLinks('/wiki/Kevin_Bacon')
print('links 길이: ', len(links))
while len(links) > 0:
    newArticle = links[random.randint(0, len(links) - 1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# links 길이:  447
# /wiki/Will.i.am
# /wiki/Facebook
# /wiki/AOL
# /wiki/List_of_Yahoo!-owned_sites_and_services
# /wiki/Yahoo!_Kimo
# /wiki/OneSearch
# /wiki/Swedish_language
# /wiki/N%C3%A4rke
# /wiki/%C3%96rebro_Hundred
# /wiki/Swedish_language
# /wiki/Greek_language
# /wiki/Yevanic_language
# /wiki/Israelites
# /wiki/Groups_claiming_affiliation_with_Israelites
# /wiki/S2CID_(identifier)
# /wiki/Bibliometrics
# /wiki/History_and_philosophy_of_science
# /wiki/Vitalism
# /wiki/Blending_inheritance
# /wiki/Genetic_assimilation
# /wiki/Hsp90
# /wiki/SAE1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 21
#      19 newArticle = links[random.randint(0, len(links) - 1)].attrs['href']
#      20 print(newArticle)
# ---> 21 links = getLinks(newArticle)
#
# Cell In[77], line 10, in getLinks(articleUrl)
#       9 def getLinks(articleUrl):
# ---> 10     html = urlopen('https://en.wikipedia.org' + articleUrl)
#      11     bs = BeautifulSoup(html, 'html.parser')
#      12     bodyContent = bs.find('div', {'id' : 'bodyContent'})
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/urllib/request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/PY_39/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 전체 사이트 데이터 수집 소스

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
count = 0
def getLinks(pageUrl):
    global pages
    global count
    html = urlopen('https://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text()) # <h1>태그 검색
        # print(bs.find(id = 'mw-content-text).find('p').text)
        print(bs.find('div', attrs = {'id' : 'mw-content-text'}).find('p').text)
    except AttributeError as e:
        print('this page is missing something! Continuing: ', e)

    pattern = '^(/wiki/)((?!:).)*$'
    for link in bs.find_all('a', href = re.compile(pattern)):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                print('-' * 40)
                count += 1
                print(f'[{count}]: {newPage}')
                pages.add(newPage)
                getLinks(newPage)

getLinks('')
# Out:
# Main Page
# Worlds is the debut studio album by American electronic music producer Porter Robinson, released on August 12, 2014, by Astralwerks. Initially known for his heavier bass-centric production, Robinson became increasingly dissatisfied with the electronic dance music (EDM) genre, believing it limited his artistic expression. Following the release of his 2012 single "Language", Robinson decided to prioritize aesthetic and emotional qualities in his work, taking inspiration from media that evoked nostalgia for his childhood and integrating elements taken from anime, films, and sounds from 1990s video games. The album was promoted with four singles and later a tour (pictured) in North America and Europe. Worlds was well-received by most critics, who praised it as innovative and forecasted a promising career for Robinson, though others felt the record lacked coherence or was unexciting. The album has been retrospectively noted for its impact on the EDM scene. (Full article...)
#
# ----------------------------------------
# [1]: /wiki/Main_Page
# ----------------------------------------
# [2]: /wiki/Wikipedia
# ----------------------------------------
# [3]: /wiki/Free_content
# ----------------------------------------
# [4]: /wiki/Encyclopedia
# ----------------------------------------
# [5]: /wiki/English_language
# ----------------------------------------
# [6]: /wiki/Worlds_(Porter_Robinson_album)
# ----------------------------------------
# [7]: /wiki/Electronic_music
# ----------------------------------------
# [8]: /wiki/Porter_Robinson
# ----------------------------------------
# [9]: /wiki/Astralwerks
# ----------------------------------------
# [10]: /wiki/Electronic_dance_music

# %% [markdown]
# ## 인터넷 크롤링: URL 구조

# %%
from urllib.parse import urlparse

urlString1 = 'https://shopping.naver.com/home/p/index.naver'

url = urlparse(urlString1)
print(url.scheme)
print(url.netloc)
print(url.path)
# Out:
# https
# shopping.naver.com
# /home/p/index.naver

# %% [markdown]
# ## 네이버 블로그 검색

# %%
from urllib.request import urlopen
from urllib.parse import quote
import requests
from bs4 import BeautifulSoup

query = 'ChatGPT'
url = f'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query={query}'
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')

html = urlopen(url)
soup = BeautifulSoup(html.read(), 'html.parser')
blog_results = soup.select('a.title_link')
print('검색 결과수: ', len(blog_results))
search_count = len(blog_results)
desc_results = soup.select('a.dsc_link') # 검색된 블로그의 간단한 설명

for blog_title in blog_results:
    title = blog_title.text
    link = blog_title['href']
    print(f'{title}, [{link}]')
# Out:
# 검색 결과수:  30
# 실무중심 ChatGPT 교육 프로젝트 기초부터 배우기!, [https://blog.naver.com/dmsdud0395/223541085715]
# 챗GPT 무료 유료 차이 ChatGPT 4.0 할인 팁, [https://blog.naver.com/vovov77/223544018515]
# chatgpt 4.0 사용법 무료 가능할까, [https://blog.naver.com/guitarjeus/223519289429]
# [ChatGPT 활용] 콘텐츠 생성하는 방법 배운 수강기, [https://blog.naver.com/songin06/223541110860]
# chatgpt교육 메디치교육센터 무료로 배우고 취업하기!, [https://blog.naver.com/stacy0701/223517997493]
# 아이폰, 맥북 써야 할 이유 추가? Chat GPT-4o, 맥용 ChatGPT 앱 공개!, [https://post.naver.com/viewer/postView.naver?volumeNo=37811478&memberNo=724&vType=VERTICAL]
# 챗GPT 무료 유료 사용법, ChatGPT 4o 할인, [https://blog.naver.com/yjg01212/223508371016]
# chatgpt 4.0 사용법 chatgpt 4o 차이 챗지피티 무료 유료 챗gpt 가격 chat gpt 4 할인 그림 공유, [https://blog.naver.com/cayque/223497361289]
# 챗gpt 유료 사용법 지피티 chatgpt 4o 할인, [https://blog.naver.com/toresi/223482446100]
# nfxbus 할인코드 가격과 ChatGPT 활용방법, [https://blog.naver.com/ahspzk2000/223522077702]
# ChatGPT 기반의 아이폰 통화 녹음기 PLAUD NOTE, [https://blog.naver.com/obama8775/223485767945]
# 쳇GPT chatGPT 사용 블로그마케팅과 sns 마켓팅 교육, [https://blog.naver.com/whaldud88/223512366705]
# ChatGPT-4o-mini 활용 이메일 에이전트 만들기(노션, MAKE), [https://blog.naver.com/jubileo/223541035359]
# 챗GPT 무료 유료 차이 ChatGPT 4o 사용법 가격 할인, [https://blog.naver.com/01198916129/223530455366]
# 영어 공부를 위한 번역 어플 비교(구글 번역기 vs 파파고 vs ChatGPT), [https://blog.naver.com/takebody/223543888094]
# 챗지피티 3.5 무료 vs ChatGPT 4o 유료 버전 차이, [https://blog.naver.com/okok1326/223526916886]
# 키보드 없는 채팅 시대: ChatGPT 음성 모드의 신세계 열리다!, [https://blog.naver.com/manonthetrek/223544720495]
# [프롬프트 작성] 영어 교사를 위한 찐 실전 ChatGPT - 생성형 AI 영어수업 활용하기, [https://blog.naver.com/dbfans/223530548642]
# ChatGPT 4o 달라진 점과 주요 특징, [https://blog.naver.com/cafe_blue/223503637081]
# Canva와 ChatGPT로 북클럽 워크시트 만들기, [https://blog.naver.com/smartbookclub/223539953001]
# 윈도우 PC에서 인공지능 ChatGPT 앱으로 설치하는 방법, [https://blog.naver.com/feena74/223532165969]
# 삼성SDS 첼로스퀘어 ChatGPT 런칭 소식 및 사용법 정리, [https://blog.naver.com/soary81/223510534637]
# 챗GPT(ChatGPT)를 활용해 엑셀 함수 수식 구하기, [https://blog.naver.com/kingpro_/223541996729]
# ChatGPT 미친 활용법 알아볼까? 이게되네 챗GPT 도서 리뷰, [https://blog.naver.com/chaosily/223528085942]
# chatgpt를 활용하여 수업 자료, 발표 자료(파워포인트) 간단히 만들어보기, [https://blog.naver.com/nabilera1/223537735455]
# 넷플릭스 공유, Chatgpt4 계정 겜스고에서 저렴하게 (할인코드 있음), [https://blog.naver.com/copy98/223523972548]
# [비전공자를 위한 ChatGPT 활용 데이터 분석] 회귀분석에서 SST, SSR, SSE, R2의 개념 및 사례, [https://blog.naver.com/hijunggon/223544149123]
# 챗gpt 무료 유료 사용법 ChatGPT 4o 할인 방법, [https://blog.naver.com/here_i/223544191333]
# 카톡 ChatGPT AskUp, [https://blog.naver.com/spdlxmtkwjf/223445891671]
# chatGPT로 데이터 분석, 미래 예측, [https://blog.naver.com/lastvalue/223512051061]

# %%
for i in range(search_count):
    title = blog_results[i].text
    link = blog_results[i]['href']
    print(f'{title}, [{link}]')
    print(desc_results[i].text)
    print('-' * 80)
# Out:
# 실무중심 ChatGPT 교육 프로젝트 기초부터 배우기!, [https://blog.naver.com/dmsdud0395/223541085715]
# AI에게 일을 빼앗기기 전에 ChatGPT 교육을 받아두는 게 좋겠다는 판단이 섰어요. 지금 일하는 곳은 컴퓨터 전산 처리 등을 사용하지만 언제 인공 지능 시스템으로 넘어갈지 알 수... 초보가 ChatGPT 교육부터 시작해서 AI와 IT 세계에 발을 들이려니 여간 어려운 게 아니었어요. 그래서 학원에서 배우는 것이 가장 빠른 길이겠다 싶었고 등록하러 간 곳은 마침 멘토링 서비스로...
# --------------------------------------------------------------------------------
# 챗GPT 무료 유료 차이 ChatGPT 4.0 할인 팁, [https://blog.naver.com/vovov77/223544018515]
# 유료 ChatGPT 4.0 : 차별화된 성능 무료 버전의 한계를 느끼게 되면, 결국 유료 멤버십으로 업그레이드를 고민하게 되는데요. 제가 직접 사용해 본 결과 챗GPT 4.0은 한 차원 높은 성능을 제공했습니다. 우선 가장 큰 차이점은 데이터 학습량입니다. ChatGPT 4.0 기준, 수천억에서 수조 개의 파라미터가 사용되어 더욱 정교한 대화가 가능해졌고 대화의 흐름도...
# --------------------------------------------------------------------------------
# chatgpt 4.0 사용법 무료 가능할까, [https://blog.naver.com/guitarjeus/223519289429]
# chatgpt 4.0 사용법 무료 가능할까에 대한 꿀팁을 한번 방출해보도록 하겠습니다! chatgpt 4.0 사용법 우선 사용법에 대해서 간략하게 설명을 드려볼게요. 방법은 어렵지 않은데 조금 더 퀄리티를 높이고 싶다면 아주 자세하게 이야기를 해주어야 해요. 저는 유료버전을 사용하고 있는데 한번 예시를 들어볼게요. 컴퓨터 또는 핸드폰 어디든 사용을 하실 수 있어요. 저는...
# --------------------------------------------------------------------------------
# [ChatGPT 활용] 콘텐츠 생성하는 방법 배운 수강기, [https://blog.naver.com/songin06/223541110860]
# 가장 대표적인 것 중 하나가 바로 업무에서 ChatGPT 활용을 하기 시작한 거죠. 이전에는 사람이 하던 데이터 분석이나 자료 분석을 이제는 AI가 하기 시작했습니다. AI 기술은 꼭 IT... 내부에서 업무 성과를 내고, 능력을 인정받기 위해서는 업무 효율성을 높일 수 있는 ChatGPT 활용 기술을 배우는 게 필요합니다. IT 산업과 관련이 없을 것 같은 제조, 유통, 기획, 문서 제작...
# --------------------------------------------------------------------------------
# chatgpt교육 메디치교육센터 무료로 배우고 취업하기!, [https://blog.naver.com/stacy0701/223517997493]
# 오늘은 제가 chatgpt교육 받고 있는 후기를 전해드리려고 해요. 직업을 구하고 있는 상황이었는데요. 어느 분야에서 어떠한 일을 할지 진지한 시각으로 고민하기 시작했어요. 갈수록... 이러한 트렌드 역시 제가 다른 것 보다 chatgpt교육 받고 싶었던 커다란 이유라고 손꼽을 수 있어요. 게다가 생성형 ai는 웹툰을 비롯해 영화, 콘텐츠 등에 쓰일 수 있거든요. 어도비라는...
# --------------------------------------------------------------------------------
# 아이폰, 맥북 써야 할 이유 추가? Chat GPT-4o, 맥용 ChatGPT 앱 공개!, [https://post.naver.com/viewer/postView.naver?volumeNo=37811478&memberNo=724&vType=VERTICAL]
# OpenAI는 GPT-4o를 발표하면서 모든 사람이 ChatGPT를 사용하기 쉽고 자연스럽게 사용할 수 있게 하기 위해서 개발 중이라고 밝혔습니다. 이를 위해서 데스크톱 앱 버전을 출시했고, 웹 UI 업데이트를 진행했습니다. 그리고 현재 제공하고 있는 서비스들을 모든 사람들이 사용할 수 있게 무료로 제공할 예정이라고 밝혔습니다. 여기에 무료 사용자 용량 제한이 5배로...
# --------------------------------------------------------------------------------
# 챗GPT 무료 유료 사용법, ChatGPT 4o 할인, [https://blog.naver.com/yjg01212/223508371016]
# 물론, 가볍게 활용하기만 하는 목적이라면 무료 버전인 ChatGPT 3.5만으로도 충분합니다. 하지만 2021년 9월 이후의 정보가 많지 않아 최신성 면에서는 큰 한계를 안고 있다는 점, 여기에 느린 응답 속도와 제한된 데이터량까지 쾌적하게 이용하는 데는 이쉬움이 제법 있는 편입니다. 반면, 유료 버전(Plus 멤버십)인 ChatGPT 4.0는 DALL-E 기반의 이미지 생성과 함께...
# --------------------------------------------------------------------------------
# chatgpt 4.0 사용법 chatgpt 4o 차이 챗지피티 무료 유료 챗gpt 가격 chat gpt 4 할인 그림 공유, [https://blog.naver.com/cayque/223497361289]
# 이번 시간에는 OpenAI의 인공지능 chatgpt 사용법과 최근 업데이트 출시된 chatgpt 4o의 차이점 그리고 chatgpt 4.0 싸게 할인받는법에 대해 살펴보겠습니다. chatgpt 3.5 Free 플랜 버전은 수년 전의 정보를 기준으로 하고 어휘력도 부족한데다 텍스트만 지원하기 때문에 현재 무료입니다. chatgpt 4.0 즉 GPT Plus는 최신의 정보 및 빠른 응답속도를 제공하고 있으며...
# --------------------------------------------------------------------------------
# 챗gpt 유료 사용법 지피티 chatgpt 4o 할인, [https://blog.naver.com/toresi/223482446100]
# 진정 퀄리티 있는 제품을 만나보세요 ㅎㅎ ∇∇∇ 거의 공짜 수준, 80% 싸게 현명한 소비하는 방법 ∇∇∇ 위 링크로 들어가면 chatgpt 4o , mt-gpt, 스포티파이, 파라마운트, 타이달, youtube premium 등 더 많은 서비스도 만나볼 수 있어요. 이용자가 많아질수록 자리가 부족할 수 있으니, 서두르세요! (지난 주 유튜브 프리미엄은 품절이 되어서 가입이 불가능했어요....
# --------------------------------------------------------------------------------
# nfxbus 할인코드 가격과 ChatGPT 활용방법, [https://blog.naver.com/ahspzk2000/223522077702]
# 최근에 학생 분들 중에는 ChatGPT를 활용하시는 분들도 계시지요? 저도 학습을 하면서 필요한 부분은 챗GPT로 도움을 받을 수도 있었는데요. ChatGPT를 사용하기 위해서 nfxbus 할인코드를 이용하기도 한답니다. 정가보다 저렴하게 이용할 수 있어서 필요할 때 유용하게 사용할 수 있었는데요. 필요하신 분께서는 한번 참고해보시기 바랍니다. nfxbus에서는...
# --------------------------------------------------------------------------------
# ChatGPT 기반의 아이폰 통화 녹음기 PLAUD NOTE, [https://blog.naver.com/obama8775/223485767945]
# 아이폰 통화 녹음기 PLAUD NOTE 특징 PLAUD NOTE는 생산성을 향상시키기 위해 고안된 ChatGPT 기반의 혁신적인 AI 음성 녹음기입니다. 컴팩트한 크기로 설계되어 스마트폰과의 원활한... 다른 플랫폼에서는 볼 수 없는 상황별 템플릿과 마인드맵을 제공하는데, ChatGPT 기반이라서 사람이 직접 한 것처럼 회의록을 목차별로 깔끔하게 정리를 해주기도 하고, 강의에서 주제와...
# --------------------------------------------------------------------------------
# 쳇GPT chatGPT 사용 블로그마케팅과 sns 마켓팅 교육, [https://blog.naver.com/whaldud88/223512366705]
# 쳇GPT chatGPT 사용 블로그마케팅 등 마켓팅 교육 자주 내리는 비가 역시나 내리던 7월 9일 아침 7시 이전에 일어나 페이스북을 보다가 페친님이 포스팅 한 ai 인공지능 적용한 교육을... 쳇GPT chatGPT를 사용하는 마켓팅이라 기대가 됩니다 블로그 페이스북 인스타그램 유튜브 게다가 쇼핑몰까지 가능하다니 기대감 뿜뿜입니다 교육을 하시는 염요일 교수님이 운영하는...
# --------------------------------------------------------------------------------
# ChatGPT-4o-mini 활용 이메일 에이전트 만들기(노션, MAKE), [https://blog.naver.com/jubileo/223541035359]
# ChatGPT를 활용해서, 이메일 에이전트를 만들면 어떨까? 생각해봤습니다. 메일이 오면 ChatGPT가 자동으로 분석을 해서 노션에 업데이트 해주는거죠 이렇게 기본 구조를 만들고 나면, 그 후 응용은 무궁무진 할 듯 합니다. 노션자동화에 많이들 쓴다는 MAKE를 사용했습니다. 무료로 월 1000번 작업 가능하니, 일단 무료로 먼저 테스트 해보시면 될거...
# --------------------------------------------------------------------------------
# 챗GPT 무료 유료 차이 ChatGPT 4o 사용법 가격 할인, [https://blog.naver.com/01198916129/223530455366]
# 챗GPT 무료 유료 차이 ChatGPT 4o 사용법 가격 할인 인공지능 기술이 일상 깊숙이 자리 잡으면서, 많은 분들이 챗GPT라는 도구에 대해 궁금증을 가지고 계실 텐데요. 이 글에서는 챗GPT의 무료 유료 버전의 차이, 사용 방법, 그리고 경제적으로 이용할 수 있는 팁까지 상세하게 다뤄보겠습니다. 무료 유료 버전의 성능 차이 무료 버전인 ChatGPT 3.5는 로그인 없이...
# --------------------------------------------------------------------------------
# 영어 공부를 위한 번역 어플 비교(구글 번역기 vs 파파고 vs ChatGPT), [https://blog.naver.com/takebody/223543888094]
# ChatGPT ChatGPT를 사용했을 때 단순 해석뿐만 아니라 왜 이렇게 이야기 했을지에 대해 추측까지 해줍니다. 역사적 맥락이나 특정 사건과 관련? 2차 세계대전 때 독일의 히틀러가 폴란드를 침공하면서 전쟁을 시작한 것을 빗대어 표현을 한 것이 아닐까라는 생각이 들더군요. 조크를 좋아하는 챈들러의 캐릭터와 어우러져 이제서야 상황이 이해가...
# --------------------------------------------------------------------------------
# 챗지피티 3.5 무료 vs ChatGPT 4o 유료 버전 차이, [https://blog.naver.com/okok1326/223526916886]
# 그중에서도 OpenAI의 ChatGPT는 대화형 AI 중에서 가장 높은 인지도를 보유하고 있는 서비스 중 하나죠. 모두 유료일 것 같지만, 의외로 챗지피티는 3.5 버전 기준으로는 무료 사용도 가능한데요. 그럼 더 유료버전이자 더 최신의 버전인 ChatGPT 4o와는 어떤 차이가 있는지, 또 할인받을 방도는 없는지 한번 알아보도록 하겠습니다. 목차 1. 챗지피티 3.5 vs ChatGPT 4o...
# --------------------------------------------------------------------------------
# 키보드 없는 채팅 시대: ChatGPT 음성 모드의 신세계 열리다!, [https://blog.naver.com/manonthetrek/223544720495]
# ChatGPT가 이제 말을 할 수 있다고 하네요! 단순히 TTS를 통한 텍스트 읽기가 아닌, 실제 인간의 소통에 가까운 말하기가 가능한 수준에 도달한 듯합니다. 어떠세요? 놀랍지 않나요?... 이 새로운 기능은 'ChatGPT 고급 음성 모드'라고 불린대요. 지금은 '챗GPT 플러스(ChatGPT Plus)' 가입자 중 일부 유료 회원들만 사용할 수 있지만, 올 가을까지 보다 더 많은 사람들이 이용할 수...
# --------------------------------------------------------------------------------
# [프롬프트 작성] 영어 교사를 위한 찐 실전 ChatGPT - 생성형 AI 영어수업 활용하기, [https://blog.naver.com/dbfans/223530548642]
# 1) ChatGPT에 단어와 표현 파일을 첨부하고 프롬프트를 쓴다. 사진에 있는 프롬프트도 좋았지만, 한 번에 만들기 위해서 여러번 고민했더니 아래와 같은... ChatGPT의 경우 초등학생은 교사의 시연을 통해 간접 체험만 가능! 뤼튼은 사용 가능하지만 부모나 법적 보호자의 허락이 필요하다. 이번에 많이 활용했던 후카츠식...
# --------------------------------------------------------------------------------
# ChatGPT 4o 달라진 점과 주요 특징, [https://blog.naver.com/cafe_blue/223503637081]
# ChatGPT 새 버전을 결제해 써보고 있다. 가격은 월 22달러로, 약 3만 원. 사실 강의만 아니면 개인적으로는 챗지피티 유료 버전 쓸 일이 거의 없다. 가끔 홍보용 포스팅 만들 때... ChatGPT 버전별 비교 특징 ChatGPT-3.5 ChatGPT-4 ChatGPT-4o 모델 크기 1750억 개의 파라미터 수십억 개의 추가 파라미터 GPT-4기반 추가 개선 대화의 자연스러움 향상됨 크게 향상 최고 수준의...
# --------------------------------------------------------------------------------
# Canva와 ChatGPT로 북클럽 워크시트 만들기, [https://blog.naver.com/smartbookclub/223539953001]
# Canva로 만들고 ChatGPT로 채워요. https://blog.naver.com/smartbookclub/222267723950 Canva를 이용하면 시각적으로 매력있는 워크시트를 체계적으로 정리하면서 만들기 어렵지 않아요. 사실 더 문제는 안에 채워지는 내용인데요. 그 부분은 ChatGPT가 완벽하게 해결해줍니다. 저의 비서, ChatGPT가 어떤 일들을 하고 있는 지 잠시 살펴볼께요. 챕터 5를 읽고 질문하기를 진행할...
# --------------------------------------------------------------------------------
# 윈도우 PC에서 인공지능 ChatGPT 앱으로 설치하는 방법, [https://blog.naver.com/feena74/223532165969]
# 저 역시도 최근 OpenAI ChatGPT를 사용하여 프로그래밍하는 데 도움을 많이 받고 있는데, 업계에서 일하는 동생이 말하기를~ "요즘 개발자들은 인터넷이 안 되는 데서 근무를 시키면 실력이 반 이하로 준다."라고 하더니 정말 거짓이 아닌 것 같습니다. 뭐 사실 인공지능 ChatGPT가 아니라도 인터넷이 안되는데 가면, 코딩하는데 애로사항이 꽃 피는 것은 사실이죠. 서두가...
# --------------------------------------------------------------------------------
# 삼성SDS 첼로스퀘어 ChatGPT 런칭 소식 및 사용법 정리, [https://blog.naver.com/soary81/223510534637]
# 글로벌 물류 플랫폼 삼성SDS 첼로스퀘어가 디지털 물류 플랫폼으로는 최초로 ChatGPT 서비스를 GPT스토어에 런칭하였습니다. ChatGPT는 Open AI사의 대화형 인공지능 서비스로 일상, 업무, 학습, 취미생활 등 다양한 분야에서 활용되고 있는 중이라 이미 다들 잘 아실 거라 생각합니다. 덕분에 앞으로는 더 쉽고 간편하게 Cello Square의 주요 기능들을 이용할 수 있게...
# --------------------------------------------------------------------------------
# 챗GPT(ChatGPT)를 활용해 엑셀 함수 수식 구하기, [https://blog.naver.com/kingpro_/223541996729]
# 앞에서는 다양한 ChatGPT 활용 방법에 대해서 살펴보았습니다. https://blog.naver.com/kingpro_/223522573664 https://blog.naver.com/kingpro_/223531072470 이번 시간에는 ChatGPT를 활용해 엑셀의 수식을 구하는 방법을 살펴보겠습니다. 챗GPT를 활용해 엑셀 함수 수식 구하기 아쉽게도 ChatGPT가 코파일럿처럼 엑셀 함수나 결과값을 완벽히 보장해주지는 않습니다. 하지만...
# --------------------------------------------------------------------------------
# ChatGPT 미친 활용법 알아볼까? 이게되네 챗GPT 도서 리뷰, [https://blog.naver.com/chaosily/223528085942]
# 필자의 경우엔 ChatGPT4o를 이용해서 여러 업무를 하고 있습니다. 단순 작업은 물론 그림을 생성하거나 엑셀, 문서 작업을 하고, 보고서 초안을 작성하는 등 여러가지 업무를 챗GPT를... ChatGPT 미친 활용법 알아볼까? 이게되네 챗GPT 도서 리뷰 저자인 오힘찬 작가는 14년차 테크 칼럼리스트이자 마케터입니다. 그리고, 최근 2년 동안 실제 업무에 적용한 AI 활용 사례를...
# --------------------------------------------------------------------------------
# chatgpt를 활용하여 수업 자료, 발표 자료(파워포인트) 간단히 만들어보기, [https://blog.naver.com/nabilera1/223537735455]
# #chatgpt활용 #수업자료제작방법 중학교 수학 수업용 파워포인트를 만드는 과정에서 ChatGPT를 활용하면, 시간과 노력을 절약하면서도 효율적이고 흥미로운 콘텐츠를 제작할 수 있습니다. 무슨 단원을 만들지 정하면 됩니다. 일단 너무 쉽고 모든 교과에서 활용 가능합니다. 프로그래밍 수업에서도 가능합니다. 디테일한 프롬프트를 만들기 어려우면 전체적인 아웃라인만...
# --------------------------------------------------------------------------------
# 넷플릭스 공유, Chatgpt4 계정 겜스고에서 저렴하게 (할인코드 있음), [https://blog.naver.com/copy98/223523972548]
# 오늘은 넷플뿐만 아니라 chatgpt4, 디저, 어도비, 오피스등의 다양한 계정을 저렴하게 이용할 수 있는 겜스고를 소개하려고합니다. 5% 할인코드도 있어요 한국에 진출한지 3년된곳이고... ChatGPT4도 있고요 디즈니 플러스도 지원하는데, 1년 단일로만 판매하고 있습니다. 겜스고에서 취급하는 스트리밍 계정들 넷플릭스, 유튜브 프리미엄, 스포티파이, 타이달, 디저...
# --------------------------------------------------------------------------------
# [비전공자를 위한 ChatGPT 활용 데이터 분석] 회귀분석에서 SST, SSR, SSE, R2의 개념 및 사례, [https://blog.naver.com/hijunggon/223544149123]
# 이번 시간에는 비전공자를 위한 ChatGPT 활용 데이터 분석 과정의 회귀분석에서 SST, SSR, SSE, R2의 개념 및 사례에 대해 알아보겠습니다. 시험 점수와 공부 시간 상황: 학생들의 시험 점수와 그들이 공부한 시간을 조사하여 데이터를 확보했다고 가정해 보겠습니다. 이제 이 데이터를 바탕으로, "공부 시간"이 "시험 점수"를 얼마나 잘 설명할 수 있는지를 알아보려고...
# --------------------------------------------------------------------------------
# 챗gpt 무료 유료 사용법 ChatGPT 4o 할인 방법, [https://blog.naver.com/here_i/223544191333]
# ChatGPT는 사용자가 프롬프트를 어떻게 작성하냐에 따라 대답이 달라지기 때문에, 프롬프트를 잘 작성하는 것이 중요합니다. 가능한 세부적인 질문을 하세요. 예를 들어, [내가... 따라서 조금 더 최신 정보가 포함되고, 자연스러운 대화, 복잡한 문제 해결, 창의적 작업, 더 빠른 응답 등이 가능한 더 발전된 언어 모델의 ChatGPT를 이용하고 싶다면 GPT-4 또는 GPT...
# --------------------------------------------------------------------------------
# 카톡 ChatGPT AskUp, [https://blog.naver.com/spdlxmtkwjf/223445891671]
# AskUp 요즘 인공지능 ai시대에 챗지피티(chatGPT)에 대해 많이 들어왔었고 나도 저번에 로또번호 추첨이라든지 몇개를 재미로 물어봤었다. 근데 카톡에도 이 기능이 있는줄 몰랐네?... askup 검색했을때 다음과 같이 뜨는데 저기 파란색 체크되어있는게 바로 카톡 chatGPT인 AskUp이다. 친구 추가하게되면 AskUp과 대화할수 있게 될것이다. AskUp과 친구가 되면 이런 장문의...
# --------------------------------------------------------------------------------
# chatGPT로 데이터 분석, 미래 예측, [https://blog.naver.com/lastvalue/223512051061]
# chatGPT에 데이터를 전달하고, 향후 5년의 결과를 예측해 달라고 하자. (엑셀 파일을 첨부해도 되고, 이미지로 캡처해서 데이터를 전달해도 잘 인식한다) ((GPT에 질문)) 다음... chatGPT에서 만들어주는 챠트에서 한글이 깨지거나 표기도지 않을 때, 한글 폰트가 설치되어 않아서 그런 것이기 때문에 "다음의 사이트에서 파일을 다운로드 받아서...
# --------------------------------------------------------------------------------
