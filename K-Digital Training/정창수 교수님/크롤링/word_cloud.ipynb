# %% [markdown]
# ## Okt 간단 예제 #1

# %%
from konlpy.tag import Okt
okt = Okt() # Open Korean Text (과거 트위터 형태소 분석기)
text = "마음에 꽂힌 칼한자루 보다 마음에 꽂힌 꽃한송이가 더 아파서 잠이 오지 않는다"

# pos(text): 문장의 각 품사를 태깅
# norm=True: 문장을 정규화, stem=True: 어간을 추출
okt_tags = okt.pos(text, norm=True, stem=True)
print(okt_tags)

# nouns(text): 명사만 리턴
okt_nouns = okt.nouns(text)
print(okt_nouns)
# Out:
# [('마음', 'Noun'), ('에', 'Josa'), ('꽂히다', 'Verb'), ('칼', 'Noun'), ('한', 'Determiner'), ('자루', 'Noun'), ('보다', 'Verb'), ('마음', 'Noun'), ('에', 'Josa'), ('꽂히다', 'Verb'), ('꽃', 'Noun'), ('한송이', 'Noun'), ('가', 'Josa'), ('더', 'Noun'), ('아프다', 'Adjective'), ('잠', 'Noun'), ('이', 'Josa'), ('오지', 'Noun'), ('않다', 'Verb')]
# ['마음', '칼', '자루', '마음', '꽃', '한송이', '더', '잠', '오지']

# %% [markdown]
# ## Okt 예제 #2

# %%
from konlpy.tag import Okt

text = """나랏말이 중국과 달라 한자와 서로 통하지 아니하므로,
    우매한 백성들이 말하고 싶은 것이 있어도 마침내 제 뜻을 잘 표현하지 못하는 사람이 많다.
    내 이를 딱하게 여기어 새로 스물여덟 자를 만들었으니,
    사람들로 하여금 쉬 익히어 날마다 쓰는 데 편하게 할 뿐이다."""

okt = Okt()

# morphs(text): 텍스트를 형태소 단위로 나눔
okt_morphs = okt.morphs(text)
print('morphs():\n', okt_morphs)

# 명사만 추출
okt_nouns = okt.nouns(text)
print('nouns():\n', okt_nouns)

# phrases(text): 어절 추출
okt_phrases = okt.phrases(text)
print('phrases():\n', okt_phrases)

# pos(text): 품사를 태깅
okt_pos = okt.pos(text)
print('pos():\n', okt_pos)
# Out:
# morphs():
#  ['나랏말', '이', '중국', '과', '달라', '한자', '와', '서로', '통', '하지', '아니하므로', ',', '\n    ', '우매', '한', '백성', '들', '이', '말', '하고', '싶은', '것', '이', '있어도', '마침내', '제', '뜻', '을', '잘', '표현', '하지', '못', '하는', '사람', '이', '많다', '.', '\n    ', '내', '이를', '딱하게', '여기어', '새로', '스물', '여덟', '자를', '만들었으니', ',', '\n    ', '사람', '들', '로', '하여금', '쉬', '익히어', '날', '마다', '쓰는', '데', '편하게', '할', '뿐', '이다', '.']
# nouns():
#  ['나랏말', '중국', '달라', '한자', '서로', '통', '우매', '백성', '말', '것', '마침내', '제', '뜻', '표현', '사람', '내', '스물', '여덟', '사람', '쉬', '날', '데', '뿐']
# phrases():
#  ['나랏말', '중국', '중국과 달라', '중국과 달라 한자', '중국과 달라 한자와 서로', '중국과 달라 한자와 서로 통', '우매', '백성들', '마침내', '마침내 제', '마침내 제 뜻', '표현', '못하는 사람', '스물여덟', '사람들', '달라', '한자', '서로', '사람', '스물', '여덟']
# pos():
#  [('나랏말', 'Noun'), ('이', 'Josa'), ('중국', 'Noun'), ('과', 'Josa'), ('달라', 'Noun'), ('한자', 'Noun'), ('와', 'Josa'), ('서로', 'Noun'), ('통', 'Noun'), ('하지', 'Verb'), ('아니하므로', 'Adjective'), (',', 'Punctuation'), ('\n    ', 'Foreign'), ('우매', 'Noun'), ('한', 'Josa'), ('백성', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('말', 'Noun'), ('하고', 'Josa'), ('싶은', 'Verb'), ('것', 'Noun'), ('이', 'Josa'), ('있어도', 'Adjective'), ('마침내', 'Noun'), ('제', 'Noun'), ('뜻', 'Noun'), ('을', 'Josa'), ('잘', 'Verb'), ('표현', 'Noun'), ('하지', 'Verb'), ('못', 'VerbPrefix'), ('하는', 'Verb'), ('사람', 'Noun'), ('이', 'Josa'), ('많다', 'Adjective'), ('.', 'Punctuation'), ('\n    ', 'Foreign'), ('내', 'Noun'), ('이를', 'Verb'), ('딱하게', 'Adjective'), ('여기어', 'Verb'), ('새로', 'Adjective'), ('스물', 'Noun'), ('여덟', 'Noun'), ('자를', 'Verb'), ('만들었으니', 'Verb'), (',', 'Punctuation'), ('\n    ', 'Foreign'), ('사람', 'Noun'), ('들', 'Suffix'), ('로', 'Josa'), ('하여금', 'Adverb'), ('쉬', 'Noun'), ('익히어', 'Verb'), ('날', 'Noun'), ('마다', 'Josa'), ('쓰는', 'Verb'), ('데', 'Noun'), ('편하게', 'Adjective'), ('할', 'Verb'), ('뿐', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation')]

# %% [markdown]
# ## 예제: 단어 분석 및 Word Cloud 생성 #1

# %%
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import platform
import numpy as np
from PIL import Image

text = open('test.txt', encoding='utf-8').read()
okt = Okt() # Open Korean Text 객체 생성

# okt함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag = []
sentences_tag = okt.pos(text)

noun_adj_list = []
# tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for word, tag in sentences_tag:
    if tag in ['Noun', 'Adjective']:
        noun_adj_list.append(word)

print(noun_adj_list)
# 가장 많이 나온 단어부터 50개를 저장한다.
counts = Counter(noun_adj_list)
tags = counts.most_common(50)
print(tags)

# 한글을 분석하기위해 font를 한글로 지정, macOS는 .otf, windows는 .ttf 파일의 위치를 지정
if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'
elif platform.system() == 'Darwin': # Mac OS
    path = r'/System/Library/Fonts/AppleGothic'
else:
    font = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

img_mask = np.array(Image.open('cloud.png'))
wc = WordCloud(font_path = path, width = 400, height = 400,
                background_color='white', max_font_size=200,
                repeat=True, colormap = 'inferno', mask = img_mask)

cloud = wc.generate_from_frequencies(dict(tags))
# 생성된 WordCloud를 test.jpg로 보낸다.
# cloud.to_file('text.jpg')
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['우리나라', '경우', '보통', '여', '년', '단위', '구분', '대표', '세대', '중반', '산업화', '세대', '중반', '초반', '베이비부머', '세대', '세대', '세대', '중후', '반', '세대', '일명', '밀레니엄', '세대', '그', '이후', '세대', '있다', '이중', '우리나라', '청년', '세대', '세대', '수', '있다', '같은', '듯', '다른', '세대', '이', '무엇', '세대', '시대', '반영', '세대', '임', '먼저', '세대', '사이', '세대', '용어', '이', '용어', '캐나다', '작가', '더글라스', '커플', '랜드', '소설', '세대', '유래', '당시', '주목', '이', '소설', '기성세대', '다르지만', '정의', '힘든', '젊은', '세대', '칭', '마케팅', '기업', '선택', '말', '마땅하게', '정의', '용어', '없다', '뜻', '사용', '적절했기', '때문', '삐삐', '통한', '연락', '카세트', '테이프', '일종', '워크맨', '이', '세대', '경제', '풍요', '동시', '를', '세대', '체적', '시사', '경제', '쪽', '관심', '많은', '것', '특징', '당시', '경제', '풍요', '가운데', '새로운', '문화', '개인주의', '남', '차별', '화하는', '개성', '중시', '세대', '문화', '대표', '예', '거기', '컬러', '대중화', '대중문화', '성장하기', '시작', '당시', '선풍', '인기', '서태지', '아이', '은', '개성', '넘치는', '이미지', '세대', '열렬한', '지지', '이외', '홍콩영화', '다문화', '시대', '세대', '주름', '가장', '진보', '세대', '명칭', '현재', '세대', '기성세대', '역사상', '가장', '젊은', '타이틀', '토대', '세대', '특징', '간직', '소비', '트렌드', '주도하는', '세대', '자리매', '세대', '세대', '말로', '여기', '매사', '긍정', '참여', '점', '어떤', '일', '대답', '세대', '뜻', '약자', '이', '세대', '스마트폰', '를', '주로', '사용', '인스타그램', '등', '로', '소통', '욜', '족', '워', '라벨', '족', '등', '다양하게', '세대', '달리', '오프라인', '아닌', '온라인', '시대', '아날로그', '디지털', '공유', '밀레니엄', '세대', '불리', '기도', '이', '세대', '시절', '보', '시절', '향수', '자극', '것', '반응', '대표', '수원', '행리', '등', '레트로', '풍', '골목', '공유', '점', '특징', '또', '각종', '디지털', '기기', '발전', '몸소', '세대', '사회', '미', '버디버디', '싸이월드', '등', '그리워하는', '경향', '있다', '이', '세대', '가장', '특징', '지금', '이', '순간', '의', '행복', '위', '투자', '걸', '점', '이', '때문', '욜', '비', '가격', '대비', '마음', '만족', '추구', '워', '라벨', '등', '많은', '신조어', '탄생', '기도', '이러한', '면', '외', '연애', '결혼', '출산', '포기', '포', '세대', '나', '여러', '가지', '포기', '포', '세대', '어', '두운', '면도', '동시', '존재', '세대', '기도', '세대', '경우', '사이', '세대', '뜻', '세대', '다음', '의미', '세대', '컬', '며', '사물', '인터넷', '시대', '각종', '를', '사용', '다양성', '중시', '세대', '수', '있다', '세대', '달리', '처음', '온라인', '주요', '무대', '활동', '세대', '인터넷', '친숙하며', '컴퓨터', '스마트폰', '익숙하고', '텍스트', '이미지', '동영상', '콘텐츠', '선호', '편이', '방증', '듯', '세대', '가시', '유튜브', '감상', '제일', '유튜브', '통해', '검색', '등', '더', '생생하게', '정보', '선호', '세대', '를', '감상', '자라', '온', '것', '다른', '모습', '또한', '세대', '로부터', '자유로운', '가치관', '이전', '세대', '다양성', '중시', '편이', '일', '자체', '의미', '를', '더', '중요하게', '생각', '일과', '삶', '균형', '중시', '등', '특징', '대화', '비방', '같은', '듯', '다른', '대별', '트렌드', '이', '세대', '각자', '선호', '대화방', '다르다', '설문조사', '결과', '의하면', '세대', '음성', '통화', '세대', '세대', '모바일', '메신저', '선호', '답', '세대', '모바일', '메신저', '가장', '선호', '반면', '음성', '통화', '싫은', '이유', '대해', '세대', '다른', '세대', '말', '때', '침묵', '싫어서', '상대방', '말', '즉시', '대답', '통화', '동안', '다른', '일', '수', '없어서', '음성', '통화', '피', '응답', '많았다', '모바일', '메신저', '가장', '선호', '세대', '타', '세대', '달리', '온라인', '친구', '만들기', '적극', '때', '를', '접', '세대', '특징', '오프라인', '대인', '관계', '시간', '부족한', '학생', '모바일', '메신저', '대인', '관계', '형성', '자신', '표현', '수단', '사용', '적절하기', '때문', '각', '대별', '선호', '상품', '상이', '온라인', '쇼핑몰', '해', '기준', '전', '대비', '연령', '대별', '판매', '증감', '률', '비교', '분석', '결과', '세대', '기기', '및', '각종', '취미', '용품', '세대', '뉴트로', '추구', '성향', '뚜렷', '우선', '세대', '소비', '주', '근무', '제로', '가시', '늘', '자기계발', '취미', '생활', '대한', '관심', '변화', '이로', '인해', '나이', '초월', '개인', '취향', '제품', '선택', '자유롭게', '소비', '트렌드', '확대', '가장', '눈', '점', '작동', '정도', '지식', '요하', '디지털', '기기', '대한', '수요', '전', '대비', '급증', '점', '구체', '노트북', '웨어', '러블', '디바이스', '증가', '헬리', '캠', '드론', '무려', '배', '훌쩍', '신장', '세', '최근', '젊은', '층', '필수품', '자리', '잡고', '있는', '블루투스', '이어폰', '구매', '세대', '역시', '나', '급증', '취미', '생활', '젊어졌다', '같은', '기간', '개인', '나', '유튜브', '등', '콘텐츠', '제작', '필요한', '영상', '촬영', '용품', '량', '게임', '용품', '체력', '민첩함을', '요하', '스포츠', '연령', '경계', '서핑보드', '중장', '년층', '전', '대비', '전동', '킥', '보드', '자전거', '각각', '증가', '세대', '경우', '복고', '레트로', '를', '선호', '경향', '뚜렷하다', '실제', '레트로', '취미', '활동', '대표', '격인', '화폐', '주화', '우표', '수집', '용품', '경우', '판매량', '전', '대비', '증가', '것', '집계', '턴테이블', '오디오', '라디오', '수요', '덩달아', '증가', '또한', '우리', '전통', '복인', '한복', '일상생활', '젊은', '층', '패션', '캐', '주얼', '한복', '수요', '같은', '기간', '한복', '모습', '등', ...
# [('세대', 89), ('소비', 17), ('등', 16), ('이', 14), ('유튜브', 14), ('것', 13), ('명', 12), ('있다', 11), ('수', 11), ('를', 10), ('선호', 10), ('더', 9), ('자신', 9), ('영향', 9), ('크리에이터', 9), ('트렌드', 8), ('점', 8), ('있는', 8), ('중', 8), ('다른', 7), ('특징', 7), ('문화', 7), ('가장', 7), ('취미', 7), ('콘셉트', 7), ('중시', 6), ('현재', 6), ('달리', 6), ('통해', 6), ('브랜드', 6), ('대표', 5), ('같은', 5), ('젊은', 5), ('온라인', 5), ('대비', 5), ('만족', 5), ('편이', 5), ('제품', 5), ('플렉스', 5), ('경우', 4), ('일명', 4), ('시대', 4), ('용어', 4), ('말', 4), ('없다', 4), ('사용', 4), ('관심', 4), ('비', 4), ('의미', 4), ('모습', 4)]

# %% [markdown]
# ## 영문 wordcloud 예제

# %%
from wordcloud import wordcloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

text = open('alice.txt').read()
STOPWORDS.add('said')
print('STOPWORDS:', STOPWORDS)

img_mask = np.array(Image.open('cloud.png'))

wordcloud = WordCloud(width=400, height=400,
                      background_color="white", max_font_size=200,
                      stopwords=STOPWORDS,
                      repeat=True,
                      colormap='inferno', mask=img_mask).generate(text)

# words_: 객체의 비율 정보가 담긴 딕셔너리 변환
print(wordcloud.words_)

plt.figure(figsize = (10, 8))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# STOPWORDS: {"here's", 'who', 'such', 'few', "where's", 'its', 'said', 'same', 'only', 'she', 'too', 'further', 'than', 'no', 'should', 'your', 'is', 'and', "we'll", 'http', 'did', 'ever', "i'd", 'having', 'before', 'myself', 'all', 'not', 'does', 'both', "shouldn't", 'however', 'about', 'for', 'some', 'their', 'any', 'during', 'on', 'yours', 'can', "she'll", 'by', 'ours', 'where', "wouldn't", 'from', "can't", 'while', "we're", 'i', 'down', 'nor', 'between', 'k', 'how', 'of', 'own', 'doing', 'until', "they're", 'at', 'being', 'or', "she'd", 'there', 'had', 'in', 'hence', 'were', "how's", 'up', "who's", "they'd", 'why', 'that', 'otherwise', 'whom', 'else', 'like', 'other', "you'd", "we'd", 'because', 'over', 'when', 'am', 'his', "doesn't", "they'll", 'to', 'so', 'my', "they've", "hasn't", 'with', 'these', 'are', "there's", 'if', 'have', "isn't", 'each', 'against', 'her', 'they', 'hers', 'been', 'r', 'into', 'just', 'be', "you've", 'has', "he's", 'it', "that's", 'which', "it's", 'theirs', 'ourselves', 'you', 'out', 'ought', "don't", 'yourself', 'themselves', 'would', "he'll", "mustn't", 'after', 'since', 'once', "we've", 'cannot', 'could', 'most', 'but', 'here', 'below', "didn't", 'do', 'then', 'get', "hadn't", 'the', 'them', 'again', 'above', 'those', "what's", 'com', 'this', 'yourselves', 'an', 'off', "let's", 'was', "wasn't", 'me', "you're", 'him', "aren't", 'our', 'he', 'more', "i'll", "shan't", "couldn't", "weren't", "she's", 'therefore', 'also', "i've", 'itself', 'a', 'shall', "won't", "why's", 'under', 'herself', 'we', "you'll", "i'm", "haven't", 'as', 'www', 'very', 'himself', 'through', "when's", 'what', "he'd"}
# {'Alice': 1.0, 'little': 0.29508196721311475, 'one': 0.27595628415300544, 'know': 0.2459016393442623, 'went': 0.226775956284153, 'thing': 0.2185792349726776, 'time': 0.2103825136612022, 'Queen': 0.20765027322404372, 'see': 0.1830601092896175, 'King': 0.17486338797814208, 'well': 0.1721311475409836, 'now': 0.16393442622950818, 'head': 0.16393442622950818, 'began': 0.15846994535519127, 'way': 0.1557377049180328, 'Hatter': 0.1557377049180328, 'Mock Turtle': 0.15300546448087432, 'say': 0.15027322404371585, 'Gryphon': 0.15027322404371585, 'think': 0.1448087431693989, 'quite': 0.14207650273224043, 'much': 0.13934426229508196, 'first': 0.13934426229508196, 'thought': 0.1366120218579235, 'go': 0.1366120218579235, 'come': 0.13114754098360656, 'never': 0.1284153005464481, 'voice': 0.12568306010928962, 'looked': 0.12295081967213115, 'got': 0.12295081967213115, 'must': 0.12021857923497267, 'Cat': 0.12021857923497267, 'Duchess': 0.11475409836065574, 'Mouse': 0.11202185792349727, 'round': 0.11202185792349727, 'back': 0.1092896174863388, 'two': 0.1092896174863388, 'Dormouse': 0.1092896174863388, 'make': 0.10382513661202186, 'Oh': 0.10109289617486339, 'tone': 0.10109289617486339, 'eye': 0.09836065573770492, 'came': 0.09562841530054644, 'last': 0.09289617486338798, 'nothing': 0.09289617486338798, 'tell': 0.09289617486338798, 'day': 0.09016393442622951, 'large': 0.09016393442622951, 'great': 0.09016393442622951, 'hand': 0.09016393442622951, 'found': 0.08743169398907104, 'long': 0.08743169398907104, 'door': 0.08743169398907104, 'minute': 0.08743169398907104, 'looking': 0.08743169398907104, 'put': 0.08469945355191257, 'word': 0.08469945355191257, 'March Hare': 0.08469945355191257, 'made': 0.08196721311475409, 'heard': 0.08196721311475409, 'look': 0.07923497267759563, 'will': 0.07923497267759563, 'replied': 0.07923497267759563, 'might': 0.07650273224043716, 'Caterpillar': 0.07650273224043716, 'seemed': 0.07377049180327869, 'going': 0.07377049180327869, 'right': 0.07377049180327869, 'away': 0.07103825136612021, 'without': 0.07103825136612021, 'moment': 0.07103825136612021, 'course': 0.07103825136612021, 'thought Alice': 0.07103825136612021, 'Rabbit': 0.06830601092896176, 'next': 0.06830601092896176, 'rather': 0.06830601092896176, 'soon': 0.06830601092896176, 'yet': 0.06830601092896176, 'dear': 0.06557377049180328, 'took': 0.06557377049180328, 'take': 0.06557377049180328, 'sure': 0.06557377049180328, 'sort': 0.06284153005464481, 'felt': 0.06284153005464481, 'added': 0.06284153005464481, 'getting': 0.060109289617486336, 'Let': 0.060109289617486336, 'three': 0.060109289617486336, 'find': 0.060109289617486336, 'White Rabbit': 0.060109289617486336, 'upon': 0.05737704918032787, 'wish': 0.05737704918032787, 'question': 0.05737704918032787, 'side': 0.05737704918032787, 'till': 0.05737704918032787, 'arm': 0.05737704918032787, 'use': 0.0546448087431694, 'anything': 0.0546448087431694, 'end': 0.0546448087431694, 'good': 0.0546448087431694, 'please': 0.0546448087431694, 'half': 0.0546448087431694, 'face': 0.0546448087431694, 'cried': 0.0546448087431694, 'tried': 0.05191256830601093, 'even': 0.05191256830601093, 'house': 0.05191256830601093, 'tea': 0.05191256830601093, 'eat': 0.05191256830601093, 'curious': 0.05191256830601093, 'wonder': 0.04918032786885246, 'table': 0.04918032786885246, 'enough': 0.04918032786885246, 'something': 0.04918032786885246, 'jury': 0.04918032786885246, 'court': 0.04918032786885246, 'another': 0.04644808743169399, 'spoke': 0.04644808743169399, 'perhaps': 0.04644808743169399, 'talking': 0.04644808743169399, 'begin': 0.04644808743169399, 'sat': 0.04644808743169399, 'asked': 0.04644808743169399, 'Bill': 0.04644808743169399, 'ran': 0.04371584699453552, 'air': 0.04371584699453552, 'bit': 0.04371584699453552, 'turned': 0.04371584699453552, 'garden': 0.04371584699453552, 'indeed': 0.04371584699453552, 'hastily': 0.04371584699453552, 'change': 0.04371584699453552, 'seen': 0.040983606557377046, 'idea': 0.040983606557377046, 'saying': 0.0409836 ...

# %% [markdown]
# ## 네이버 뉴스 타이틀 Word Cloud 예제 #1

# %%
from bs4 import BeautifulSoup
import requests
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
import platform
import numpy as np
from PIL import Image

def get_titles(start_num, end_num, search_word, title_list):
    # start_num ~ end_num까지 크롤링
    while start_num <= end_num:
        url = ('https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}&start={}'.\
               format(search_word, start_num))
        
        req = requests.get(url)
        time.sleep(1)
        if req.ok: # 정상적인 request 확인
            soup = BeautifulSoup(req.text, 'html.parser')
            news_titles = soup.find_all('a', {'class' : 'news_tit'})
            for news in news_titles:
                title_list.append(news['title'])
        start_num += 10
        print('title 개수:', len(title_list))
        print(title_list)

def make_wordcloud(title_list, stopwords, word_count):
    okt = Okt()
    sentences_tag = []
    # 형태소 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-' * 80)

    noun_adj_list = []
    # 명사와 형용사, 영단어(Alpha)를 리스트에 추가
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective', 'Alpha']:
                noun_adj_list.append(word)

    # 형태소별 count
    counts = Counter(noun_adj_list)
    tags = counts.most_common(word_count)
    print('-' * 80)
    print(tags)

    tag_dict = dict(tags)

    # 검색어 제외 방법 2: dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)

    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin': # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

    img_mask = np.array(Image.open('cloud.png'))
    wordcloud = WordCloud(font_path = path, width = 800, height = 600,
                    background_color='white', max_font_size=200,
                    repeat=True, colormap = 'inferno', mask = img_mask)

    cloud = wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10,8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()

if __name__ == '__main__':
    search_word = 'ChatGPT' # 검색어 지정
    title_list = []
    stopwords = [search_word, '데이터'] # wordcloud에서 제외할 단어

    # 1~200번 게시글 까지 크롤링
    get_titles(1, 200, search_word, title_list)

    # 단어 50개까지 wordcloud로 출력
    make_wordcloud(title_list, stopwords, 50)
# Out:
# title 개수: 10
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집']
# title 개수: 20
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"']
# title 개수: 30
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들']
# title 개수: 40
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시']
# title 개수: 50
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도']
# title 개수: 60
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!"]
# title 개수: 70
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"']
# title 개수: 80
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine']
# title 개수: 90
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 100
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 110
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 120
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 130
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 140
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 150
# ["[울산소식] 춘해보건대 교직원 대상 '챗 지피티 활용' 워크숍 등", "유진투자증권-모트에이아이, '증권업 AI 전환' MOU 체결", '춘해보건대, 교직원 대상 ChatGPT 활용 원격교육 역량강화 워크숍', '경산시, 공무원 AI 역량 강화 교육 성료', 'S. Korea eases decade-old financial regulations, opening door for AI', "에이전트소프트, 해피캠퍼스 AI글쓰기 서비스 'EasyAI' 기능 선보여", '[대구가톨릭대 소식] 대구가톨릭대 김소연 씨, 전국영양사학술대회서 우수논문초록상 수상', "수원시 '인공지능 리터러시 교육' 수강생 모집", "[수원 소식] '정조대왕 능행차 공동재연' 참여 정조대왕·혜경궁 홍씨역 맡을 시민 공모", '[DBR/알립니다]‘ChatGPT 마스터 클래스 4기’ 수강생 모집', '수원시, ‘인공지능 리터러시 특강’ 수강생 모집', 'NCIA 교육센터, 하반기 A·ChatGPT 관련 재직자 무료 교육 과정 개설', '[12일 수원시] 합성고무바닥재 놀이터 환경안전검사 실시 등', 'OpenAI Raises Red Flags: ChatGPT-4o Users Swayed by AI’s Human-Like Allure', '카톡부터 챗GPT까지…스마트한 강서구 시니어', "대구가톨릭대, 'SW·AI활용 관련 현직 교사 연수' 성료", "신경과에서 \ufeffChatGPT 적용하면 '전공의 1년차 수준'", '차세대융합콘텐츠산업협회 교육센터, 하반기 AI, ChatGPT 관련 재직자 무료 교육 과정 개설', '한국사회의 Al 전략은?', 'AI가 꼽은 하반기 여행 트렌드…"깊이 있는 여행"', "OpenAI 'ChatGPT 감지기' 완성, 99.9% 정확도에도 공개 미룬다?", '‘이게 머니’ 만능 전자결제⋯ 현금은 서러워 [창간 36주년, 빅체인지]', 'KAIST 김재철AI대학원 ‘머신러닝 엔지니어 부트캠프’ 수강생 모집 16일까지', 'Audi to launch Q6 e-tron equipped with ChatGPT in South Korea early next year', '[논설실의 서가] AI 시대의 슬기롭고 평등한 교육 방식', '대구가톨릭대 현직 교사 연수 마쳐', '"예적금 금리 오늘이 가장 높다"…목돈 어떻게 굴릴까?', "[수원시 소식] 합성고무바닥재 놀이터 57개소 환경안전검사 모두 '적합'·이재준 수원시장, 극동방송 '나라사랑축제' 개회선언·'인공지능(AI)리터러시 특강' 수강생 모집", 'How Google’s Antitrust Defeat Might Transform Big Tech', '"지금이 \'저가\'다"… 자사주 매입에 분주한 상장 기업 임원들', '카톡부터 챗GPT까지… 스마트한 강서구 시니어', "JPMorgan Chase Transforms Work for 60,000 Employees with AI Assistant Powered by OpenAI's ChatGPT", "소진공, '2024 디지털 역량 강화 교육' 진행", '피규어 신형 휴머노이드 로봇 공개, 오픈AI ChatGPT 탑재', "효과도, 참여율도 저조한 '밸류업'...불길 살릴 수 있나", 'Can You Be Emotionally Reliant on an A.I. Voice? OpenAI Says Yes.', "노동약자 지원법? 플랫폼·가짜3.3 등 '오분류 노동자' 시정부터![오민규의 인사이드 경제]", '인간 능가하는 AGI…인류 마지막 발명품 될 것인가', '부여군, ChatGPT 활용 홍보역량 강화교육 성료', '심사평가원 감사실, 감사인 대상 생성형 AI 활용 교육 실시', 'AI could be the breakthrough that allows humanoid robots to jump from science fiction to reality', '[신간] 이게 되네? 챗GPT 미친 활용법 51제', '춘해보건대, 교직원 쳇GPT 활용 교육', "15년 차 교사가 챗GPT로 '숙제봇' 만들었습니다", '강원교육연수원 횡성분원, 교원 챗GPT 활용 연수', '오픈AI, ChatGPT 생성 콘텐츠 감지 도구 공개 보류', 'OpenAI Debates Watermarking ChatGPT Amid User Backlash Concerns', '디지털 시대의 글쓰기 교육, ‘AI 튜터’와 함께', "Apple's Premium Apple Intelligence Subscription Rumors Heat Up as 3-Year Launch Window Looms", 'ChatGPT가 그린 토요일(3일) 서울 날씨 : 최고 35도', '전북디자인센터, 디자인 아카데미 교육 개최', '요즘 마케터의 성공 방식 “ChatGPT로 프로마케터 되기 원데이 워크숍” 8월 29일 개최', '전남도, 남도 여행· ‘OK 전남관광’ 챗봇에 물어봐', 'Elon Musk Revives Lawsuit Against OpenAI and Sam Altman', "IPO 몰리는데 주가는 마이너스?...더본코리아·아이엠포텐 등 '부실 상장' 논란까지", '엠클라우드브리지, ‘즉시 사용 가능한’ 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', '“카톡부터 챗GPT까지”…강서구, 중장년층을 위한 ‘강서 스마트한교실’ 운영', '道, ‘OK 전남관광’ 챗봇 오픈', '전북디자인센터, 전북특별자치도 디자인 아카데미 교육', "'OK 전남관광' 챗봇에 물어봐!", '"우리 집만 \'누수\'라면 일상생활배상책임 보상 못 받는다"', 'OpenAI Extends DALL-E 3 Image Generation to Free Users, But Limits Apply', '대전디자인진흥원, 생성형 AI 활용한 디자인 엔지니어링 실무 교육 개최', '엠클라우드브리지, 기업용 OpenAI & ChatGPT 업무 플랫폼 출시', "[IPO] 공모가 밴드상단 확정 '유라클'...이달 6~7일 18만여주 일반청약", "대전디자인진흥원 '2024년 지역디자인인프라 구축사업'", '윤성임 AI비즈마케팅, 생성형AI(GenAI)가 혁신하는 마케팅 패러다임 : 개인화와 자동화', "한남대-유원대, 폭염보다 더 뜨거운 한남대 학생들의 창업 열기로 '2024년 창업동아리(클럽) 연합 간담회' 성료", "엠클라우드브리지, '즉시 사용 가능한' OpenAI & ChatGPT 업무 플랫폼 출시", '티메프 사태, 10년 전 몰디브 악몽 재현?... 신혼여행 만큼은 "온라인 여행사 못 믿겠다!"', '\'美 주식 주간거래 중단\'으로 취소된 금액 6300억원 달해…금감원 "자율 조정 추진"', 'Tech Bosses Preach Patience as They Spend and Spend on A.I.', '순천대, 저학년 대상 진로탐색 캠프 개최', '스마트팜 데이터, ChatGPT가 분석하고 운영 도와줘', '병원 내 챗GPT 활용, 환자교육 분야에서 효과 기대', '"주가 과도하게 눌려있다"…삼성증권, 3분기 코스피 3050 전망', 'OpenAI Launches Advanced Voice Mode for ChatGPT Plus, Video Features Coming Soon', "AI가 불러올 전력수요 '급증'…전력망 확대･개선에 '주목'", '건축기술인회, 함께하는 미래교육연구소와 ChatGPT 입문교육 시행', 'ChatGPT Search Engine', '세종시, 외국인 주민 언어장벽 허물기 나서', 'Scarlett Johansson sabe lo que quiere', 'Meta in Talks to Use Voices of Judi Dench, Awkwafina and Others for A.I.', "남도 여행은 'OK 전남관광' 챗봇에 물어봐요", '[이진규의 AI 이야기] ChatGPT등 LLM의 한계를 극복하는 RAG 챗봇', "하루만에 '반대매매' 약 5배 급증...공매도 금지 이후 최대", 'AI 산업, 소비자의 채팅봇 무관심 속 정체', '에이블런, ChatGPT 업무 활용 백서 교육과정 출시 프로모션 진행', 'Sales of Macs and iPad ...
# title 개수: 160
# ...
# --------------------------------------------------------------------------------
# [('일', 'Modifier'), ('론', 'Noun'), ('머스크', 'Noun'), ('오픈', 'Noun'), ('AI', 'Alpha'), ('에', 'Josa'), ('새', 'Noun'), ('소송', 'Noun'), (',', 'Punctuation'), ('샘', 'Noun'), ('알트', 'Noun'), ('만', 'Josa'), ('기만', 'Noun'), ('주장', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('명재곤', 'Noun'), ('의', 'Josa'), ('증시', 'Noun'), ('산책', 'Noun'), (']', 'Punctuation'), ('애널', 'Noun'), ('리스트', 'Noun'), ('와', 'Josa'), ('기자', 'Noun'), ('를', 'Josa'), ('믿는가', 'Verb')]
# --------------------------------------------------------------------------------
# [('ChatGPT', 'Alpha'), ('가', 'Verb'), ("'", 'Punctuation'), ('최고', 'Noun'), ('의', 'Josa'), ('CRO', 'Alpha'), ("'", 'Punctuation'), ('라', 'Josa'), ('할', 'Verb'), ('때', 'Noun'), ('까지', 'Josa'), ('…', 'Punctuation'), ('우정', 'Noun'), ('바이오', 'Noun'), ('는', 'Josa'), ("'", 'Punctuation'), ('변신', 'Noun'), ('중', 'Noun'), ("'", 'Punctuation')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('누가', 'Noun'), ('제일', 'Noun'), ('잘하나', 'Verb'), ('②', 'Foreign'), (']', 'Punctuation'), ('“', 'Foreign'), ('여행가이드', 'Noun'), (',', 'Punctuation'), ('어떤', 'Adjective'), ('AI', 'Alpha'), ('에', 'Josa'), ('맡길까', 'Verb'), ('”', 'Foreign')]
# --------------------------------------------------------------------------------
# [('영월군', 'Noun'), (',', 'Punctuation'), ('여성', 'Noun'), ('기업인', 'Noun'), ('동아리', 'Noun'), ('정기회', 'Noun'), ('의', 'Josa'), ('및', 'Noun'), ('ChatGpt', 'Alpha'), ('활용', 'Noun'), ('법', 'Noun'), ('교육', 'Noun')]
# --------------------------------------------------------------------------------
# [('ChatGPT', 'Alpha'), ('가', 'Verb'), ('알려주는', 'Verb'), ('정보', 'Noun')]
# --------------------------------------------------------------------------------
# [('Elon', 'Alpha'), ('Musk', 'Alpha'), ('Takes', 'Alpha'), ('Aim', 'Alpha'), ('at', 'Alpha'), ('Sam', 'Alpha'), ('Altman', 'Alpha'), (':', 'Punctuation'), ('Refiles', 'Alpha'), ('Explosive', 'Alpha'), ('Lawsuit', 'Alpha'), ('Against', 'Alpha'), ('OpenAI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('"', 'Punctuation'), ('공포', 'Noun'), ('에', 'Josa'), ('산다', 'Noun'), ('"', 'Punctuation'), ('개인', 'Noun'), (',', 'Punctuation'), ('이', 'Determiner'), ('달', 'Noun'), ('만', 'Josa'), ('5조원', 'Number'), ('대', 'Foreign'), ('순', 'Modifier'), ('매수', 'Noun'), ('…', 'Punctuation'), ('저가', 'Noun'), ('매수', 'Noun'), ('타깃', 'Noun'), ('은', 'Josa'), ("'", 'Punctuation'), ('반도체', 'Noun'), ('주', 'Noun'), ("'", 'Punctuation')]
# --------------------------------------------------------------------------------
# [('OpenAI', 'Alpha'), ('Director', 'Alpha'), ('John', 'Alpha'), ('Schulman', 'Alpha'), ('Joins', 'Alpha'), ('Amazon', 'Alpha'), ('-', 'Punctuation'), ('Backed', 'Alpha'), ('Anthropic', 'Alpha'), ('Amid', 'Alpha'), ('Leadership', 'Alpha'), ('Shake', 'Alpha'), ('-', 'Punctuation'), ('Up', 'Alpha')]
# --------------------------------------------------------------------------------
# [('인카', 'Noun'), ('금융', 'Noun'), ('서비스', 'Noun'), (',', 'Punctuation'), ('임', 'Noun'), ('직원', 'Noun'), ('대상', 'Noun'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('활용', 'Noun'), ('교육', 'Noun'), ('성', 'Modifier'), ('료', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('단독', 'Noun'), (']', 'Punctuation'), ('내달', 'Noun'), ("'", 'Punctuation'), ('압류', 'Noun'), ('방지', 'Noun'), ('통장', 'Noun'), ("'", 'Punctuation'), ('통합', 'Noun'), ('…', 'Punctuation'), ('취업', 'Noun'), ('이룸', 'Verb'), ('통장', 'Noun'), ('신규', 'Noun'), ('발급', 'Noun'), ('중단', 'Noun')]
# --------------------------------------------------------------------------------
# [('월', 'Noun'), ('20달러', 'Number'), ('로', 'Foreign'), ('고용', 'Noun'), ('하는', 'Verb'), ('AI', 'Alpha'), ('변호사', 'Noun'), ('with', 'Alpha'), ('챗', 'Noun'), ('GPT', 'Alpha'), ('[', 'Punctuation'), ('새', 'Modifier'), ('책', 'Noun'), (']', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('인카', 'Noun'), ('금융', 'Noun'), ('서비스', 'Noun'), (',', 'Punctuation'), ('임', 'Noun'), ('직원', 'Noun'), ('대상', 'Noun'), ("'", 'Punctuation'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('활용', 'Noun'), ("'", 'Punctuation'), ('교육', 'Noun'), ('및', 'Noun'), ('현', 'Modifier'), ('업', 'Noun'), ('활용', 'Noun'), ('확대', 'Noun')]
# --------------------------------------------------------------------------------
# [("'", 'Punctuation'), ('AI', 'Alpha'), ('가', 'Verb'), ('일자리', 'Noun'), ('뺏을까', 'Verb'), ("'…", 'Punctuation'), ('세계', 'Noun'), ('3', 'Number'), ('대', 'Verb'), ('AI', 'Alpha'), (',', 'Punctuation'), ('토론', 'Noun'), ('대회', 'Noun'), ('승자', 'Noun'), ('는', 'Josa')]
# --------------------------------------------------------------------------------
# [('엘리스', 'Noun'), ('그룹', 'Noun'), (',', 'Punctuation'), ('엘리스', 'Noun'), ('LXP', 'Alpha'), ('앞세워', 'Verb'), ('고객', 'Noun'), ('사', 'Noun'), ('규모', 'Noun'), ('고', 'Modifier'), ('성장', 'Noun'), ('이뤄', 'Verb')]
# --------------------------------------------------------------------------------
# [('ChatGPT', 'Alpha'), (',', 'Punctuation'), ('조', 'Noun'), ('바이든', 'Noun'), ("'", 'Punctuation'), ('I', 'Alpha'), ("'", 'Punctuation'), ('m', 'Alpha'), ('sick', 'Alpha'), ("'", 'Punctuation'), ('게시', 'Noun'), ('물', 'Noun'), ('모방', 'Noun')]
# --------------------------------------------------------------------------------
# [('오픈', 'Noun'), ('AI', 'Alpha'), ('가', 'Verb'), ("'", 'Punctuation'), ('GPT', 'Alpha'), ('-', 'Punctuation'), ('4', 'Number'), ('o', 'Alpha'), ('미니', 'Noun'), ("'", 'Punctuation'), ('출시', 'Noun'), ('한', 'Josa'), ('이유', 'Noun'), ('는', 'Josa'), ('?', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('OpenAI', 'Alpha'), ('Is', 'Alpha'), ('Testing', 'Alpha'), ('an', 'Alpha'), ('A', 'Alpha'), ('.', 'Punctuation'), ('I', 'Alpha'), ('.-', 'Punctuation'), ('Powered', 'Alpha'), ('Search', 'Alpha'), ('Engine', 'Alpha')]
# --------------------------------------------------------------------------------
# [('엠', 'Noun'), ('클라우드', 'Noun'), ('브리지', 'Noun'), (',', 'Punctuation'), ('‘', 'Foreign'), ('즉시', 'Noun'), ('사용', 'Noun'), ('가능한', 'Adjective'), ('’', 'Punctuation'), ('기업', 'Noun'), ('용', 'Noun'), ('OpenAI', 'Alpha'), ('&', 'Punctuation'), ('ChatGPT', 'Alpha'), ('업무', 'Noun'), ('플랫폼', 'Noun'), ('출시', 'Noun')]
# --------------------------------------------------------------------------------
# [('"', 'Punctuation'), ('It', 'Alpha'), ("'", 'Punctuation'), ('s', 'Alpha'), ('smarter', 'Alpha'), ('than', 'Alpha'), ('ChatGPT', 'Alpha'), ('":', 'Punctuation'), ('Using', 'Alpha'), ('lawtalk', 'Alpha'), ("'", 'Punctuation'), ('s', 'Alpha'), ('AI', 'Alpha'), ('assistant', 'Alpha'), ("'", 'Punctuation'), ('Superlawyer', 'Alpha'), ("'", 'Punctuation')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('누가', 'Noun'), ('제일', 'Noun'), ('잘하나', 'Verb'), ('①', 'Foreign'), (']', 'Punctuation'), ('“', 'Foreign'), ('AI', 'Alpha'), (',', 'Punctuation'), ('기후', 'Noun'), ('대응', 'Noun'), ('댐', 'Noun'), ('후보', 'Noun'), ('지', 'Josa'), ('알려줘', 'Verb'), ('”', 'Foreign')]
# --------------------------------------------------------------------------------
# [('109', 'Number'), ('번째', 'Suffix'), ('번뇌', 'Noun'), ('ChatGPT', 'Alpha'), ('4', 'Number'), ('o', 'Alpha'), ('는', 'Verb'), ('어떤', 'Adjective'), ('그림', 'Noun'), ('그릴까', 'Verb'), ('?', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('AI', 'Alpha'), ('·', 'Punctuation'), ('반도체', 'Noun'), ('ETF', 'Alpha'), ('수익률', 'Noun'), ('추락', 'Noun'), ('에도', 'Josa'), ('개미', 'Noun'), ('순', 'Modifier'), ('매수', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('보험', 'Noun'), ('&', 'Punctuation'), ('NOW', 'Alpha'), (']', 'Punctuation'), ('현', 'Modifier'), ('대', 'Modifier'), ('해상', 'Noun'), ('이', 'Josa'), ('후원', 'Noun'), ('하는', 'Verb'), ('인', 'Noun'), ('액터', 'Noun'), ('스', 'Noun'), ('코리아', 'Noun'), ('국내', 'Noun'), ('대회', 'Noun'), ('20', 'Number'), ('주년', 'Noun'), ('등', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('EU', 'Alpha'), ('AI', 'Alpha'), ('법', 'Noun'), ('으로', 'Josa'), ('보는', 'Verb'), ('K', 'Alpha'), ('-', 'Punctuation'), ('AI', 'Alpha'), ('법', 'Noun'), ('②', 'Foreign'), (']', 'Punctuation'), ('EU', 'Alpha'), ('의', 'Noun'), ('AI', 'Alpha'), ('법', 'Noun'), ('이', 'Josa'), ('한국', 'Noun'), ('에', 'Josa'), ('전하', 'Noun'), ('는', 'Josa'), ('도전', 'Noun'), ('과제', 'Noun')]
# --------------------------------------------------------------------------------
# [('인카', 'Noun'), ('금융', 'Noun'), ('서비스', 'Noun'), (',', 'Punctuation'), ('임', 'Noun'), ('직원', 'Noun'), ('대상', 'Noun'), ("'", 'Punctuation'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('활용', 'Noun'), ('’', 'Punctuation'), ('교육', 'Noun'), ('및', 'Noun'), ('현', 'Modifier'), ('업', 'Noun'), ('활용', 'Noun'), ('확대', 'Noun')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('해외', 'Noun'), ('주식', 'Noun'), ('Click', 'Alpha'), (']', 'Punctuation'), ('서학', 'Noun'), ('개미', 'Noun'), (',', 'Punctuation'), ('미', 'Adjective'), ('증시', 'Noun'), ('급락', 'Noun'), ('에도', 'Josa'), ('레버리지', 'Noun'), ('ETF', 'Alpha'), ('집중', 'Noun'), ('매수', 'Noun')]
# --------------------------------------------------------------------------------
# [('"', 'Punctuation'), ('구글', 'Noun'), ('위협', 'Noun'), ('하나', 'Noun'), ('"...', 'Punctuation'), ('오픈', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('자체', 'Noun'), ('검색', 'Noun'), ('엔진', 'Noun'), ('프로토타입', 'Noun'), ("'", 'Punctuation'), ('서치', 'Noun'), ('GPT', 'Alpha'), ("'", 'Punctuation'), ('공개', 'Noun')]
# --------------------------------------------------------------------------------
# [('동강', 'Noun'), ('대', 'Suffix'), (',', 'Punctuation'), ('‘', 'Foreign'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('·', 'Punctuation'), ('ChatGPT', 'Alpha'), ('’', 'Punctuation'), ('활용', 'Noun'), ('특강', 'Noun')]
# --------------------------------------------------------------------------------
# [('KG', 'Alpha'), ('스틸', 'Noun'), (',', 'Punctuation'), ('高', 'Foreign'), ('내', 'Determiner'), ('구성', 'Noun'), ("'", 'Punctuation'), ('넥스젠', 'Noun'), ('울트라', 'Noun'), ('플러스', 'Noun'), ('강판', 'Noun'), ("'", 'Punctuation'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('삼성', 'Noun'), ('·', 'Punctuation'), ('SK', 'Alpha'), ('·', 'Punctuation'), ('동원', 'Noun'), ('·', 'Punctuation'), ('두산', 'Noun'), ('…', 'Punctuation'), ('그룹', 'Noun'), ('사', 'Noun'), (',', 'Punctuation'), ('끊이지', 'Verb'), ('않는', 'Verb'), ('계', 'Noun'), ('열사', 'Noun'), ('합병', 'Noun'), ('비율', 'Noun'), ("'", 'Punctuation'), ('논란', 'Noun'), ("'", 'Punctuation')]
# --------------------------------------------------------------------------------
# [('삼성', 'Noun'), ('·', 'Punctuation'), ('SK', 'Alpha'), ('·', 'Punctuation'), ('동원', 'Noun'), ('·', 'Punctuation'), ('두산', 'Noun'), ('…', 'Punctuation'), ('그룹', 'Noun'), ('사', 'Noun'), (',', 'Punctuation'), ('끊이지', 'Verb'), ('않는', 'Verb'), ('계', 'Noun'), ('열사', 'Noun'), ('합병', 'Noun'), ('비율', 'Noun'), ("'", 'Punctuation'), ('논란', 'Noun'), ("'", 'Punctuation')]
# --------------------------------------------------------------------------------
# [('멕시카', 'Noun'), ('나', 'Josa'), (',', 'Punctuation'), ('AI', 'Alpha'), ('제작', 'Noun'), ('광고', 'Noun'), ('영상', 'Noun'), ('후속', 'Noun'), ('2', 'Number'), ('편', 'Noun'), ('공개', 'Noun')]
# --------------------------------------------------------------------------------
# [('If', 'Alpha'), ('A', 'Alpha'), ('.', 'Punctuation'), ('I', 'Alpha'), ('.', 'Punctuation'), ('Is', 'Alpha'), ('Coming', 'Alpha'), ('for', 'Alpha'), ('Comedy', 'Alpha'), ('Writers', 'Alpha'), (',', 'Punctuation'), ('Simon', 'Alpha'), ('Rich', 'Alpha'), ('Is', 'Alpha'), ('Ready', 'Alpha')]
# --------------------------------------------------------------------------------
# [('[', 'Punctuation'), ('주간', 'Noun'), ('증시', 'Noun'), ('전망', 'Noun'), (']', 'Punctuation'), ('"', 'Punctuation'), ('美', 'Foreign'), ('빅', 'Noun'), ('테크', 'Noun'), ('쇼크', 'Noun'), ('에', 'Josa'), ('휘청', 'Adverb'), ('"…', 'Punctuation'), ('증권', 'Noun'), ('가', 'Josa'), (',', 'Punctuation'), ('코스피', 'Noun'), ('2780', 'Number'), ('전망', 'Noun')]
# --------------------------------------------------------------------------------
# [('"\'', 'Punctuation'), ('검은', 'Adjective'), ('금요일', 'Noun'), ("'", 'Punctuation'), ('속', 'Noun'), ('수익률', 'Noun'), ('어쩌나', 'Adverb'), ('"…', 'Punctuation'), ('안전', 'Noun'), ('자산', 'Noun'), ('으로', 'Josa'), ('수요', 'Noun'), ('몰린다', 'Verb')]
# --------------------------------------------------------------------------------
# [('LG', 'Alpha'), ('전자', 'Noun'), (',', 'Punctuation'), ("'", 'Punctuation'), ('2024', 'Number'), ('GITC', 'Alpha'), ("'", 'Punctuation'), ('예선', 'Noun'), ('진행', 'Noun'), ('…', 'Punctuation'), ('글로벌', 'Noun'), ('장애', 'Noun'), ('청소년', 'Noun'), ('AI', 'Alpha'), ('역량', 'Noun'), ('강화', 'Noun'), ('지원', 'Noun')]
# --------------------------------------------------------------------------------
# [('"', 'Punctuation'), ('AI', 'Alpha'), ('버블', 'Noun'), ('터지나', 'Verb'), ('"…', 'Punctuation'), ('美', 'Foreign'), ('기술', 'Noun'), ('주', 'Noun'), ('폭락', 'Noun'), ('에', 'Josa'), ('삼전', 'Noun'), (',', 'Punctuation'), ('하이닉스', 'Noun'), ('도', 'Josa'), ('급락', 'Noun')]
# --------------------------------------------------------------------------------
# [('얼어붙은', 'Verb'), ('코스닥', 'Noun'), ('투심', 'Noun'), ('…"', 'Punctuation'), ('거래', 'Noun'), ('대금', 'Noun'), ('5~6조원', 'Number'), ('대', 'Foreign'), ('최저', 'Noun'), ('수준', 'Noun'), ('"', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('인카', 'Noun'), ('금융', 'Noun'), ('서비스', 'Noun'), (',', 'Punctuation'), ('임', 'Noun'), ('직원', 'Noun'), ('대상', 'Noun'), ('‘', 'Foreign'), ('생', 'Noun'), ('성형', 'Noun'), ('AI', 'Alpha'), ('활용', 'Noun'), ('’', 'Punctuation'), ('교육', 'Noun'), ('·', 'Punctuation'), ('현', 'Modifier'), ('업', 'Noun'), ('활용', 'Noun'), ('확대', 'Noun')]
# --------------------------------------------------------------------------------
# [('오픈', 'Noun'), ('AI', 'Alpha'), (',', 'Punctuation'), ('챗', 'Noun'), ('GPT', 'Alpha'), ('에', 'Josa'), ('새로운', 'Adjective'), ('음성', 'Noun'), ('모드', 'Noun'), ('도입', 'Noun'), ('…', 'Punctuation'), ('AI', 'Alpha'), ('와의', 'Josa'), ('대화', 'Noun'), (',', 'Punctuation'), ('더', 'Noun'), ('자연스럽고', 'Adjective'), ('즉각', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa')]
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [('AI', 63), ('ChatGPT', 45), ('교육', 38), ('활용', 28), ('OpenAI', 21), ('GPT', 19), ('디자인', 19), ('챗', 17), ('생', 16), ('성형', 15), ('출시', 15), ('A', 11), ('I', 11), ('챗봇', 11), ('대상', 10), ('s', 10), ('업무', 10), ('료', 9), ('여행', 9), ('플랫폼', 9), ('OK', 9), ('전남', 9), ('관광', 9), ('오픈', 8), ('and', 8), ('엠', 8), ('클라우드', 8), ('브리지', 8), ('등', 7), ('for', 7), ('센터', 7), ('to', 7), ('기업', 7), ('진흥', 7), ('역량', 6), ('강화', 6), ('서비스', 6), ('스마트', 6), ('법', 6), ('개최', 6), ('즉시', 6), ('사용', 6), ('가능한', 6), ('용', 6), ('Spend', 6), ('확대', 6), ('증권', 5), ('에이', 5), ('수원시', 5), ('수강생', 5)]
# {'AI': 63, '교육': 38, '활용': 28, 'OpenAI': 21, 'GPT': 19, '디자인': 19, '챗': 17, '생': 16, '성형': 15, '출시': 15, 'A': 11, 'I': 11, '챗봇': 11, '대상': 10, 's': 10, '업무': 10, '료': 9, '여행': 9, '플랫폼': 9, 'OK': 9, '전남': 9, '관광': 9, '오픈': 8, 'and': 8, '엠': 8, '클라우드': 8, '브리지': 8, '등': 7, 'for': 7, '센터': 7, 'to': 7, '기업': 7, '진흥': 7, '역량': 6, '강화': 6, '서비스': 6, '스마트': 6, '법': 6, '개최': 6, '즉시': 6, '사용': 6, '가능한': 6, '용': 6, 'Spend': 6, '확대': 6, '증권': 5, '에이': 5, '수원시': 5, '수강생': 5}
